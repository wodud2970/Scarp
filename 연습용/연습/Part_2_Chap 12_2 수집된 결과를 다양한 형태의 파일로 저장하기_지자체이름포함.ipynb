# %%
# Step 1. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다
from bs4 import BeautifulSoup     
from selenium import webdriver
import time
import sys

query_txt = input('크롤링할 키워드는 무엇입니까?: ')
f_name = input('검색 결과를 저장할 txt 파일경로와 이름을 지정하세요(예:c:\\data\\test_3.txt): ')
fc_name = input('검색 결과를 저장할 csv 파일경로와 이름을 지정하세요(예:c:\\data\\test_3.csv): ')
fx_name = input('검색 결과를 저장할 xls 파일경로와 이름을 지정하세요(예:c:\\data\\test_3.xls): ')

#Step 2. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/temp/chromedriver_240/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get("https://korean.visitkorea.or.kr/main/main.html")
time.sleep(2)  

#Step 3. 검색창의 이름을 찾아서 검색어를 입력 후 검색을 진행합니다
driver.find_element_by_id("btnSearch").click()
element = driver.find_element_by_id("inp_search")
element.send_keys(query_txt)
driver.find_element_by_link_text("검색").click()

# Step 4. 현재 페이지에 있는 내용을 화면에 출력하기

time.sleep(1)
# Out:
# 크롤링할 키워드는 무엇입니까?: 가을여행
# 검색 결과를 저장할 txt 파일경로와 이름을 지정하세요(예:c:\data\test_3.txt): c:\data\test_3.txt
# 검색 결과를 저장할 csv 파일경로와 이름을 지정하세요(예:c:\data\test_3.csv): c:\data\test_3.csv
# 검색 결과를 저장할 xls 파일경로와 이름을 지정하세요(예:c:\data\test_3.xls): c:\data\test_3.xls

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
content_list = soup.find('ul',class_='list_thumType flnon')
#print(content_list)

# 학습목표 1: 특정 항목들을 분리해서 추출하기
contents = content_list.find('div','area_txt').find('div','tit').get_text( )
print('1.내용:',contents.strip())

name = content_list.find('div','area_txt').find('p').get_text( )
print('2.지자체이름:',name.strip())
    
tag = content_list.find('div','area_txt').find('p','tag').get_text()
print('3.해쉬태그:',tag.strip())
print("\n")
# Out:
# 1.내용: 중앙선 따라 떠나는 늦가을 간이역 여행
# 2.지자체이름: 경기도 남양주시
# 3.해쉬태그: #간이역여행#감성여행#가을여행지추천#가을여행#기차여행#간이역

# %%
# Step 5. 각 항목별로 분리하여 추출하고 변수에 할당하기
no = 1
no2 =[ ]
contents2=[ ]
name2 = [ ]
tags2=[ ]

for i in content_list:
        
    try :
        contents = i.find('div','area_txt').find('div','tit').get_text( )
    except :
        continue
    else :
    
        no2.append(no)
        print('1.번호:',no)
        
        contents = i.find('div','area_txt').find('div','tit').get_text( )
        contents2.append(contents)
        print('2.내용:',contents.strip())
            
        name = i.find('div','area_txt').find('p').get_text( )
        name2.append(name)
        print('3.지자체이름:',name.strip())
    
        tag = i.find('div','area_txt').find('p','tag').get_text()
        tags2.append(tag)
        print('4.해쉬태그:',tag.strip())
        print("\n")
    
        no += 1
# Out:
# 1.번호: 1
# 2.내용: 중앙선 따라 떠나는 늦가을 간이역 여행
# 3.지자체이름: 경기도 남양주시
# 4.해쉬태그: #간이역여행#감성여행#가을여행지추천#가을여행#기차여행#간이역
#
#
# 1.번호: 2
# 2.내용: 늦가을 바다의 맛과 풍경이 어우러진 여행, 충남 보령
# 3.지자체이름: 충청남도 보령시
# 4.해쉬태그: #어르신추천코스#보령가볼만한곳#보령당일코스#천북굴단지#충청수영성#성주산자연휴양림#개화예술공원#웅천돌문화공원#무창포해수욕장#보령1박2일코스#보령2박3일코스#무장애여행지#장애인추천여행지#미식여행#겨울제철음식#체험여행#어르신여행#가을제철먹거리
#
#
# 1.번호: 3
# 2.내용: 해발 700m 숲의 하룻밤, 이색 체험 태백 가을 여행
# 3.지자체이름: 강원도 태백시
# 4.해쉬태그: #강원도#태백#태백고원자연휴양림#철암단풍군락지#단풍#철암탄광역사촌#365세이프타운#통리장#자연#가을#가족#친구#연인#여행#추천가볼만한곳#태백가볼만한곳#태백당일코스#태백1박2일코스#태백맛집#태백축제#가을제철음식#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 1.번호: 4
# 2.내용: 대추처럼 달콤한 충북알프스 가을 여행
# 3.지자체이름: 충청북도 보은군
# 4.해쉬태그: #충청북도#보은#충북알프스#충북알프스자연휴양림#오리숲길#황톳길체험장#법주사#배영숙산야초밥상#보은속리정이품송#속리산#가을#휴양림#체험#자연#가족#친구#연인#여행#추천가볼만한곳#보은가볼만한곳#보은당일코스#보은1박2일코스#보은맛집#보은축제#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 1.번호: 5
# 2.내용: 느릿하거나 우아하거나 열정적인 가을 원주 여행
# 3.지자체이름: 강원도 원주시
# 4.해쉬태그: #장애인추천코스#원주가볼만한곳#원주당일코스#치악산금강소나무숲길#원주옻문화센터#원주드림체육관#원주역사박물관#원주한지테마파크#돼지문화원#뮤지엄산#간현유원지#원주1박2일코스#원주2박3일코스#무장애여행지#장애인추천여행지#가을여행
#
#
# 1.번호: 6
# 2.내용: 한국관광공사 추천 9월 걷기여행길, 초가을의 선선함을 만끽하러 가는 길
# 3.지자체이름:
# 4.해쉬태그: #한국관광걷기여행길6선#걷기여행#가을여행#평화누리길#염하강철책길#김포가볼만한곳#낙동강세평하늘길#봉화가볼만한곳#트레킹코스#간절곶소망길#울주가볼만한곳#강화나들길#강화도령첫사랑길#강화가볼만한곳#강화산성#남도삼백리길#순천만갈대길#순천가볼만한곳#서산아라메길#녹색길#서산가볼만한곳#해미읍성#힐링#걷기여행길#추천!가을걷기_여행길#10월가볼만한곳
#
#
# 1.번호: 7
# 2.내용: 은빛 억새와 황금 들녘, 서해 낙조가 어우러진 보령 오서산 가을 여행
# 3.지자체이름: 충청남도 보령시
# 4.해쉬태그: #보령가볼만한곳#오서산#억새군락지#오서산자연휴양림#힐링여행#휴양여행#트레킹#월정사#단풍여행#공공누리#억새군락지#가을가볼만한곳#가을여행
#
#
# 1.번호: 8
# 2.내용: 전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행
# 3.지자체이름: 충청남도 서천군
# 4.해쉬태그: #공공누리#가을축제/행사#가을제철먹거리#가을제철음식#가을가볼만한곳#서해안가볼만한곳#먹방여행#구석구석미식회
#
#
# 1.번호: 9
# 2.내용: 가을은 역시 원주, 원주로 떠나는 가을 여행 원츄!
# 3.지자체이름: 강원도 원주시
# 4.해쉬태그: #가을여행#가을1박2일#원주1박2일#원주여행#출렁다리#이색책방#레일바이크#책과함께_향기로운여정
#
#
# 1.번호: 10
# 2.내용: 한국관광공사 추천 11월 걷기여행길, 빨갛게 노랗게 물든 가을을 만끽하러 가는 길
# 3.지자체이름: 서울
# 4.해쉬태그: #걷기여행길

# %%
# 학습목표 2: 분리 수집된 데이터를 데이터 프레임으로 만들어서 
# csv , xls 형식으로 저장하기
  
# 출력 결과를 표(데이터 프레임) 형태로 만들기
import pandas as pd

korea_trip = pd.DataFrame()
korea_trip['번호']=no2
korea_trip['내용']=pd.Series(contents2)
korea_trip['지자체이름']=pd.Series(name2)
korea_trip['태그']=pd.Series(tags2)

# csv 형태로 저장하기
korea_trip.to_csv(fc_name, encoding="utf-8-sig",index=False)
print(" csv 파일 저장 경로: %s" %fc_name)

# 엑셀 형태로 저장하기
import xlwt   # pip install xlwt 실행 후 수행
korea_trip.to_excel(fx_name,index=False)
print(" xls 파일 저장 경로: %s" %fx_name)

# 출력 결과를 txt 파일로 저장하기
f = open(f_name, 'a',encoding='UTF-8')
f.write(str(contents2))
f.write(str(tags2))
f.close( )
print(" txt 파일 저장 경로: %s" %f_name)
# Out:
#  csv 파일 저장 경로: c:\data\test_3.csv
#  xls 파일 저장 경로: c:\data\test_3.xls
#  txt 파일 저장 경로: c:\data\test_3.txt

# %%
# 학습목표 3: openpyxl 패키지를 활용한 엑셀 형식의 파일 관리하기

# 윈도의 cmd 창에서 pip install  openpyxl  명령과
# 윈도의 cmd 창에서 pip install xlrd 명령을 먼저 실행하세요

import openpyxl

# Step 1. 새로운 엑셀 파일을 1개 생성합니다
wb = openpyxl.Workbook( )  
wb.save("c:\\temp\\temp\\test1.xlsx")


# Step 2. 새로운 시트 생성하고 시트이름 변경하기
import openpyxl
wb = openpyxl.Workbook( )

sheet_1 = wb.active   # 현재 활성화 된 sheeet 가져오기

# 새로운 시트를 만들면서 시트 이름을 지정하기
sheet_2 = wb.create_sheet("매출현황")

# 시트 이름 변경하기
sheet_1.title = '총매출현황'

wb.save("c:\\temp\\temp\\test2.xlsx")

# Step 3. 기존 파일 불러와서 cell 에 내용 입력하기
import openpyxl

wb = openpyxl.load_workbook('c:\\temp\\temp\\test2.xlsx')
sheet_1 = wb['총매출현황']
sheet_1['A1'] = '첫번째 cell'
sheet_1['A2'] = '두번째 cell'

wb.save("c:\\temp\\temp\\test2.xlsx")
# Out:
# 1.번호: 1
# 2.내용: 중앙선 따라 떠나는 늦가을 간이역 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #간이역여행#감성여행#가을여행지추천#가을여행#기차여행#간이역
#
#
# 1.번호: 2
# 2.내용: 늦가을 바다의 맛과 풍경이 어우러진 여행, 충남 보령
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #어르신추천코스#보령가볼만한곳#보령당일코스#천북굴단지#충청수영성#성주산자연휴양림#개화예술공원#웅천돌문화공원#무창포해수욕장#보령1박2일코스#보령2박3일코스#무장애여행지#장애인추천여행지#미식여행#겨울제철음식#체험여행#어르신여행#가을제철먹거리
#
#
# 1.번호: 3
# 2.내용: 해발 700m 숲의 하룻밤, 이색 체험 태백 가을 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #강원도#태백#태백고원자연휴양림#철암단풍군락지#단풍#철암탄광역사촌#365세이프타운#통리장#자연#가을#가족#친구#연인#여행#추천가볼만한곳#태백가볼만한곳#태백당일코스#태백1박2일코스#태백맛집#태백축제#가을제철음식#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 1.번호: 4
# 2.내용: 대추처럼 달콤한 충북알프스 가을 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #충청북도#보은#충북알프스#충북알프스자연휴양림#오리숲길#황톳길체험장#법주사#배영숙산야초밥상#보은속리정이품송#속리산#가을#휴양림#체험#자연#가족#친구#연인#여행#추천가볼만한곳#보은가볼만한곳#보은당일코스#보은1박2일코스#보은맛집#보은축제#2015년10월추천가볼만한곳#10월추천가볼만한곳
#
#
# 1.번호: 5
# 2.내용: 느릿하거나 우아하거나 열정적인 가을 원주 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #장애인추천코스#원주가볼만한곳#원주당일코스#치악산금강소나무숲길#원주옻문화센터#원주드림체육관#원주역사박물관#원주한지테마파크#돼지문화원#뮤지엄산#간현유원지#원주1박2일코스#원주2박3일코스#무장애여행지#장애인추천여행지#가을여행
#
#
# 1.번호: 6
# 2.내용: 한국관광공사 추천 9월 걷기여행길, 초가을의 선선함을 만끽하러 가는 길
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #한국관광걷기여행길6선#걷기여행#가을여행#평화누리길#염하강철책길#김포가볼만한곳#낙동강세평하늘길#봉화가볼만한곳#트레킹코스#간절곶소망길#울주가볼만한곳#강화나들길#강화도령첫사랑길#강화가볼만한곳#강화산성#남도삼백리길#순천만갈대길#순천가볼만한곳#서산아라메길#녹색길#서산가볼만한곳#해미읍성#힐링#걷기여행길#추천!가을걷기_여행길#10월가볼만한곳
#
#
# 1.번호: 7
# 2.내용: 은빛 억새와 황금 들녘, 서해 낙조가 어우러진 보령 오서산 가을 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #보령가볼만한곳#오서산#억새군락지#오서산자연휴양림#힐링여행#휴양여행#트레킹#월정사#단풍여행#공공누리#억새군락지#가을가볼만한곳#가을여행
#
#
# 1.번호: 8
# 2.내용: 전어·꽃게·대하 가을 별미 삼총사와 함께한 서해안 가을 여행
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #공공누리#가을축제/행사#가을제철먹거리#가을제철음식#가을가볼만한곳#서해안가볼만한곳#먹방여행#구석구석미식회
#
#
# 1.번호: 9
# 2.내용: 가을은 역시 원주, 원주로 떠나는 가을 여행 원츄!
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #가을여행#가을1박2일#원주1박2일#원주여행#출렁다리#이색책방#레일바이크#책과함께_향기로운여정
#
#
# 1.번호: 10
# 2.내용: 한국관광공사 추천 11월 걷기여행길, 빨갛게 노랗게 물든 가을을 만끽하러 가는 길
# 3.지자체이름: 경기도 남양주시
# 4. 해쉬태그: #걷기여행길
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-9096dd1de91b> in <module>
#      34 korea_trip['번호']=no2
#      35 korea_trip['내용']=contents2
# ---> 36 korea_trip['지자체이름']=name2
#      37 korea_trip['태그']=tags2
#      38
#
# c:\python 3.5\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3470         else:
#    3471             # set column
# -> 3472             self._set_item(key, value)
#    3473
#    3474     def _setitem_slice(self, key, value):
#
# c:\python 3.5\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3547
#    3548         self._ensure_valid_index(value)
# -> 3549         value = self._sanitize_column(key, value)
#    3550         NDFrame._set_item(self, key, value)
#    3551
#
# c:\python 3.5\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3732
#    3733             # turn me into an ndarray
# -> 3734             value = sanitize_index(value, self.index, copy=False)
#    3735             if not isinstance(value, (np.ndarray, Index)):
#    3736                 if isinstance(value, list) and len(value) > 0:
#
# c:\python 3.5\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     610
#     611     if len(data) != len(index):
# --> 612         raise ValueError("Length of values does not match length of index")
#     613
#     614     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index
