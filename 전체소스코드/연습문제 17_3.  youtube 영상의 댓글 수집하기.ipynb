# %%
#-*-coding:utf-8-*-

# 연습문제 8-3: 유튜브 댓글 수집하는 크롤러

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.

from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os
import openpyxl


#Step 2. 사용자에게 검색어 키워드를 입력 받습니다.
print("=" *80)
print("연습문제 : 유투브 영상의 댓글 수집하기")
print("=" *80)


query_txt=input("1.유튜브에서 검색할 주제 키워드를 입력하세요(예:올리브영): ")

cnt = int(input('2.위 주제로 댓글을 크롤링할 유튜브 영상은 몇건입니까?:'))
reple_cnt = int(input('3.각 동영상에서 추출할 댓글은 몇건입니까?: '))

f_dir = input("4.크롤링 결과를 저장할 폴더명만 쓰세요(예:c:\\temp\\):")

print("\n")
print("요청하신 정보로 데이터를 수집중이니 잠시만 기다려 주세요~~^^")



# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt)
os.chdir(f_dir+s+'-'+query_txt)

ff_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.txt'
fc_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.csv'
fx_name=f_dir+s+'-'+query_txt+'\\'+s+'-'+query_txt+'.xls'


s_time = time.time( )


#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/spiderware_0.1/engine_238/engine.exe"
driver = webdriver.Chrome(path)

driver.get('https://www.youtube.com')

time.sleep(5)
element = driver.find_element_by_name("search_query")
element.send_keys(query_txt)
element.submit()
time.sleep(2)

#검색 결과가 첫 화면에 20개가 나옵니다.
# 만약 사용자가 입력한 동영상 개수가 20개가 넘어갈 경우 스크롤다운해서 갯수를
# 먼저 만든 후 URL 을 추출하여 URL 을 완성해야 합니다

def scroll_down(driver):
    #driver.execute_script("window.scrollTo(500,document.body.scrollHeight);")
    driver.execute_script("window.scrollBy(0,3000);") # 한페이지 20개씩 출력값
    time.sleep(5)

if reple_cnt < 20 :
        page_cnt = 1 
else :
        page_cnt = math.ceil(cnt/20)
        
if cnt > 20 :
           
        i = 1
        while ( i <=  page_cnt) :
            print("화면을 %s 회 아래로 스크롤 합니다" %i)
            scroll_down(driver)
            time.sleep(1)
            i += 1
      

# 검색된 유튜브 영상의 URL 을 추출합니다

time.sleep(2)

html = driver.page_source
soup1 = BeautifulSoup(html, 'html.parser')

count = 0
item=[]

print("\n")

for i in soup1.find_all('a','yt-simple-endpoint style-scope ytd-video-renderer'):
          
          item.append(i['href'])
          count += 1

          if count == cnt :
              break

print("검색된 영상 중 %s 건 동영상의 댓글을 추출하겠습니다" %cnt)
print("\n")

# 비트맵 이미지 아이콘을 위한 대체 딕셔너리를 만든다
bmp_map = dict.fromkeys(range(0x10000, sys.maxunicode + 1), 0xfffd)

# 수집된 전체 URL 중에서 사용자가 입력한 수만큼의 동영상의 댓글을 수집합니다.
# 먼저 전체 URL 을 완성 -> 동영상 페이지 열기 -> 댓글 수집 -> 다음 동영상 순으로 진행합니다
full_url=[]
url_cnt = 0
for x in range(0,len(item)) :
          url_cnt += 1
          url = 'https://www.youtube.com/' +item[x]
          full_url.append(url)
          if url_cnt == cnt :
            break


play_cnt = 1

url2=[]
reple2=[]
reple3=[]
reple4=[]
writer2=[]
wdate2=[]

wb=openpyxl.Workbook( )
wb.save(fx_name)


for y in range(0,len(full_url)) :
      driver.get(full_url[y])
      time.sleep(10)
      print("\n")
      print("\n")
      print("%s 번째 동영상의 정보를 수집합니다." %play_cnt)

      i = 1
      while ( i <=  page_cnt) :
      #print("화면을 %s 회 아래로 스크롤 합니다" %i)
        scroll_down(driver)
        time.sleep(10)
        i += 1
      
      html = driver.page_source
      soup2 = BeautifulSoup(html, 'html.parser')
        
      t_count_0 = soup2.select('#count')
      t_count_1 = t_count_0[1].get_text()
      t_count_2 = t_count_1.replace(",","")
      t_count_3 = re.search("\d+",t_count_2)
      t_count_4 = int(t_count_3.group())

      t_title_1 = soup2.select('#info-contents')
      t_title_2 = t_title_1[0].find('h1').get_text()
      t_title_3 = t_title_2.translate(bmp_map).replace("\n","")

      t_view_1 = soup2.find('yt-formatted-string','count-text style-scope ytd-comments-header-renderer').get_text()#.get_text( ).replace("\n","")
      t_view_2 = t_view_1.replace("," ,"")
      t_view_3 = re.search("\d+",t_view_2)
      print(t_view_1)
      t_view_4 = int(t_view_3.group())

      print("=" *80)
      print("%s 번째 동영상의 조회수는 %s 회 이고 수집할 댓글은 총 %s개 입니다" %(play_cnt,t_count_4,t_view_4))  
      print("%s 번째 동영상의 제목은 %s 입니다" %(play_cnt,t_title_3))
      print("=" *80)
      print("\n")
      print("%s 번째 동영상에서 댓글 수집을 시작합니다" %play_cnt)
      print("댓글의 개수가 많아서 시간이 걸릴 수 있으니 잠시 기다려 주세요~~^^")
      print("\n")

 #Step 5. 화면을 스크롤해서 아래로 이동합니다

      #page_cnt = math.ceil(t_view_4 / 19)

      i = 1
      while ( i <=  page_cnt+1) :
        print("%s 번째 페이지의 댓글을 수집하는 중입니다~" %i)
        scroll_down(driver)
        time.sleep(0.5)
        i += 1

      #Step 6. 내용을 수집합니다

      time.sleep(2)

      html = driver.page_source
      soup3 = BeautifulSoup(html, 'html.parser')
        
      count = 0
      d2 = 0

      reple_result = soup3.select('#comments > #sections > #contents')

      for a in range(0,reple_cnt+1) :
              count += 1
              
              f = open(ff_name, 'a',encoding='UTF-8')
              f.write("\n")
              f.write("------------------------------------------------------------------"+"\n")

             # 댓글 작성자
              try : 
                writer = reple_result[0].select("#header-author > #author-text")[a].get_text().replace("\n","").strip()
              except IndexError :
                break
              else :
                print("\n")
                print("%s 번째 영상의 %s 번째  댓글 " %(play_cnt,count))
                print("-" *70)

                # 유튜브 URL 주소
                print("1.URL 주소:",full_url[y])
                f.write("1.유투브 URL주소: " + full_url[y] + "\n")
                url2.append(full_url[y])
                
                print("2.댓글 작성자명:", writer)
                f.write("2.댓글 작성자명: " + writer + "\n")
                writer2.append(writer)
              
                # 댓글 작성일자
                wdate = reple_result[0].select("yt-formatted-string.published-time-text > a.yt-simple-endpoint")[a].get_text().replace("\n","")
            
                print("3.댓글 작성일자:",wdate)
                f.write("3.댓글 작성일자: " + wdate + "\n")
                wdate2.append(wdate)
              
                # 댓글 내용
                reple1 = reple_result[0].select('#expander > #content > #content-text')[a].get_text().replace("\n","")
            
                reple2=reple1.translate(bmp_map).replace("\n","")
                print("4.댓글 내용:",reple2)
                f.write("4.댓글 내용: " + reple2 + "\n")
                reple3.append(reple2)
                
              
              f.close( )
              
              if count == reple_cnt :
                  break
              
      time.sleep(2)       
      play_cnt += 1                

 #step 9. 엑셀 형태로 저장하기
    
              
youtube_reple = pd.DataFrame()
youtube_reple['URL 주소']=url2
youtube_reple['댓글작성자명']=pd.Series(writer2)
youtube_reple['댓글작성일자']=pd.Series(wdate2)
youtube_reple['댓글 내용']=pd.Series(reple3)


# csv 형태로 저장하기
youtube_reple.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
youtube_reple.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time

# txt 파일에 크롤링 요약 정보 저장하기
orig_stdout = sys.stdout
f = open(ff_name, 'a',encoding='UTF-8')
sys.stdout = f

print("\n")
print("=" *50)
print("총 소요시간은 %s 초 이며," %t_time)
print("총 저장 건수는 %s 건 입니다 " %count)
print("=" *50)

sys.stdout = orig_stdout
f.close( )


print("\n") 
print("=" *100)
print("1.요청된 총 %s 건 동영상 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *100)

time.sleep(3)

driver.close( )
# Out:
# ================================================================================
# 연습문제 : 유투브 영상의 댓글 수집하기
# ================================================================================
# 1.유튜브에서 검색할 주제 키워드를 입력하세요(예:올리브영): 올리브영
# 2.위 주제로 댓글을 크롤링할 유튜브 영상은 몇건입니까?:3
# 3.각 동영상에서 추출할 댓글은 몇건입니까?: 10
# 4.크롤링 결과를 저장할 폴더명만 쓰세요(예:c:\temp\):c:\data\
#
#
# 요청하신 정보로 데이터를 수집중이니 잠시만 기다려 주세요~~^^
#
#
# 검색된 영상 중 3 건 동영상의 댓글을 추출하겠습니다
#
#
#
#
#
#
# 1 번째 동영상의 정보를 수집합니다.
# 댓글 90개
# ================================================================================
# 1 번째 동영상의 조회수는 114429 회 이고 수집할 댓글은 총 90개 입니다
# 1 번째 동영상의 제목은 올리브영 세일 시오작!!!��이게 100원 이라고???!! 당장 털러 갑시다!!! 입니다
# ================================================================================
#
#
# 1 번째 동영상에서 댓글 수집을 시작합니다
# 댓글의 개수가 많아서 시간이 걸릴 수 있으니 잠시 기다려 주세요~~^^
#
#
# 1 번째 페이지의 댓글을 수집하는 중입니다~
# 2 번째 페이지의 댓글을 수집하는 중입니다~
#
#
# 1 번째 영상의 1 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 헤이즐 Heizle
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 드으디어~!!!! 우리가 기다리고 기다리던 #올리브영 #세일 입니다~!!!!����세상에 ㅠㅠㅠㅠ엄청난 세일템들과 100원템 등등어마무시한 소식들을 제가 왕창 가져왔습니당!!!다들 올리브영 털준비 되셨습니까~~??�우리 같이 낼 당장 올리브영으로 출동하자구용!!♡.♡고고~!!
#
#
# 1 번째 영상의 2 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 김가현
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 네.. 지나가는 올리브영 알바생이에요... 저는 이제 결제지옥으로 들어갈겁니다 호호호호
#
#
# 1 번째 영상의 3 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: {위즈원}DANITY
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 언니 인스타 보다가 왔는뎅 클리오 모델이라닝 � �� 저 헤로하는 물론이고 클리오 좋아했는데 진짜 클리오가 모델은 잘 뽑았네요 헤로하 찍은 거 나오지마자 클리오 털러 갑니다�‍♀️�‍♀️ 전 그럼 영상 보러..(총총)
#
#
# 1 번째 영상의 4 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 한서윤
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 올리브영 알바생인데 내일부터 죽음이네요ㅠㅠ 안그래도 바쁜데 언니때문에 더 바빠지겠어욬ㅋㅋㅋㅋㅋㅋ 그래도 항상 좋은 정보 나눔해주셔서 감사합니당�
#
#
# 1 번째 영상의 5 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 영쓰
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 아.. 어제 올리브영 쇼핑했는데... 아..ㅋㅋ 항상 내가 산 다음날에 세일하더라;;ㅠㅠ
#
#
# 1 번째 영상의 6 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 미니유
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 올영 세일해도 일본제품은 사지않기로!
#
#
# 1 번째 영상의 7 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 젠Jen
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 와 내일이구나!!!! 세일만 기다림ㅋㅋㅋㅋㅋ살거 많은데 ㅋㅋㅋ
#
#
# 1 번째 영상의 8 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 윰빈
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 언니 오늘도 너무 이뻐요.. 영역헤 (영상은 역시 헤이즐..❤️�)
#
#
# 1 번째 영상의 9 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: Mellow Raeli
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 확실히 기초템은 손등에만 테스트해볼 수 있으니깐 손등만 좋아진거 있죠 ㅋㅋㅋㅋㅋㅋㅋ 와 올리브영 ㅠㅠ 가서 털긴해야하는데 돈이 어딨지(주섬주섬)
#
#
# 1 번째 영상의 10 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=HxAkLwBQ2gU
# 2.댓글 작성자명: 김지수
# 3.댓글 작성일자: 5일 전
# 4.댓글 내용: 앰플 다 썼는데 대박! 당장 달려간다!
#
#
#
#
# 2 번째 동영상의 정보를 수집합니다.
# 댓글 265개
# ================================================================================
# 2 번째 동영상의 조회수는 45292 회 이고 수집할 댓글은 총 265개 입니다
# 2 번째 동영상의 제목은 올리브영 세일 때 ○○○ 사면 절대 손해 안 봄 [올리브영 가기 전에 꼭 봐야할 꿀템]   | 파우더룸(POWDERROOM) 입니다
# ================================================================================
#
#
# 2 번째 동영상에서 댓글 수집을 시작합니다
# 댓글의 개수가 많아서 시간이 걸릴 수 있으니 잠시 기다려 주세요~~^^
#
#
# 1 번째 페이지의 댓글을 수집하는 중입니다~
# 2 번째 페이지의 댓글을 수집하는 중입니다~
#
#
# 2 번째 영상의 1 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 쮸렛레인저
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 올영 조명 색깔 좀 바꿔주세요 제발 아주 예쁜 레드립을 샀는데 나오면 핑크...
#
#
# 2 번째 영상의 2 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: bubbly
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 삐아, 이글립스 질문에 답이 너무.... 무성의해요. PB제품홍보 1편에서 다 한거 아니었나요? 오히려 올리브영에 대한 생각이 달라집니다. 알바생들이 더 대답잘할거같아요.
#
#
# 2 번째 영상의 3 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 김소연
# 3.댓글 작성일자: 2일 전(수정됨)
# 4.댓글 내용: 하 제발 올리브영 전등!!!!!!!!!화장품매장이 노랑색전등이라니..색조 테스터를어케해보라는거냐고요ㅜㅜ
#
#
# 2 번째 영상의 4 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: Ambition Ash
# 3.댓글 작성일자: 2일 전(수정됨)
# 4.댓글 내용: 오른쪽 분 걍 웨이크메이크 좋아하시는듯..
#
#
# 2 번째 영상의 5 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 림림
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 너무 자사제품만 추천해서 좀 그렇다....신뢰도 안가고..1편에서 했으면 2편은 좀 더 다른 브랜드 설명도 듣고싶었는데
#
#
# 2 번째 영상의 6 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 니블러
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 너무 대놓고 PB 광고만 하니까 거부감드네요 신뢰감도 안가고요. 올바른 정보를 주고있는지도 안믿겨요. 애초에 PB 제작하시는 분들을 모셔온게 잘못되었다고 생각합니다. 올리브영에서 PB만 파는건 아닌데 저희가 PB 광고보자고 파우더룸 보러온거 아니잖아요;
#
#
# 2 번째 영상의 7 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 또몽
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 올리브영 편 다들 기대 했는데 차라리 올리브영 알바생들 앉혀 놓은게 더 꿀잼이였을듯웨이크메이크 필리밀리광고 영상인듯
#
#
# 2 번째 영상의 8 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 김미니
# 3.댓글 작성일자: 2일 전
# 4.댓글 내용: 흠...... 너무 올리브영 PB제품만...�
#
#
# 2 번째 영상의 9 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 김 김
# 3.댓글 작성일자: 2일 전(수정됨)
# 4.댓글 내용: 웨이크메이크 아이라이너 개구려요...심한말하기싫지만 진짜 그래요...
#
#
# 2 번째 영상의 10 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=-794mPGL2Os
# 2.댓글 작성자명: 프렌치파이
# 3.댓글 작성일자: 2일 전(수정됨)
# 4.댓글 내용: 들을만한 내용은 없네요
#
#
#
#
# 3 번째 동영상의 정보를 수집합니다.
# 댓글 705개
# ================================================================================
# 3 번째 동영상의 조회수는 797196 회 이고 수집할 댓글은 총 705개 입니다
# 3 번째 동영상의 제목은 꼭! 사야하는 올리브영 추천템�� (재구매꿀템 가득) | 민스코 Minsco 입니다
# ================================================================================
#
#
# 3 번째 동영상에서 댓글 수집을 시작합니다
# 댓글의 개수가 많아서 시간이 걸릴 수 있으니 잠시 기다려 주세요~~^^
#
#
# 1 번째 페이지의 댓글을 수집하는 중입니다~
# 2 번째 페이지의 댓글을 수집하는 중입니다~
#
#
# 3 번째 영상의 1 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 김아영
# 3.댓글 작성일자: 1주 전
# 4.댓글 내용: 이거 뒷북이긴 한데 블랙페인트 럽바 진짜 짱입니다,.. 지금까지 코팩하는게 가장 효과적인 피지 제거 방법이라고 생각했는데 아니더라고요 제 코가 그렇게 맨들맨들해지더라니까요 맨드라미인줄
#
#
# 3 번째 영상의 2 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 스폰지밥
# 3.댓글 작성일자: 1주 전
# 4.댓글 내용: 진심으로 여태 제가 본 뷰티 유투버분들 하울 영상 중에 가장 영업력 탑이신거같아요.... 진짜 다 사고 싶어요 어떡하지ㄷㄷ
#
#
# 3 번째 영상의 3 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: pick - me - up
# 3.댓글 작성일자: 7개월 전
# 4.댓글 내용: ✏제품명✏#각질빠이템 - 00:57 ~- Dr.G / 브라이트닝 필링 젤 / 19,000₩#블렉헤드빠이템 - 02:41 ~ - 23 years old / 블랙 페인트 럽바/ 14,500₩#올리브영파데추천 - 04:13 ~- espoir / 프로테일러 파운데이션 비 실크 / 38,000₩#저렴이파데브러시 - 06:45 ~- FilliMilli / V컷 파운데이션 브러시 / 13,000₩#저렴이블러셔브러시 - 08:12 ~- e.l.f / 블러셔브러시 / 7,700₩#꿀템노다지웨이크메이크 - 09:05 ~- WAKE MAKE/ Defining cover concealer / 15,000₩- WAKE MAKE / 루즈 건 제로 - 2호 킬 미 레드 / 15,000₩- WAKE MAKE / 루즈 건 제로 - 10호 빅 보스 / 15,000₩#애교살뿜뿜 - 12:43 ~- CLIO / 프리즘에어 섀도우 - 1호 텐더 라이트 / 14,000₩#대세는페리페라마스카라 - 13:42 ~- Peri Pera / 잉크 블랙 카라 - 1호 롱래시 컬링 / 10,000₩#마스크팩보다이거 - 14:58 ~- Wellage 리얼 히알루로닉 바이오 캡슐 & 블루 솔루션 / 5,900₩
#
#
# 3 번째 영상의 4 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: Minsco 민스코
# 3.댓글 작성일자: 7개월 전
# 4.댓글 내용: 이 전 배경이 나은가요? 깔꼼한 배경이 나은가요? 매번 고민이에요�새로운 마이크... 목소리 너무나 편안해서 좋은 지름이었다고 생각합니다�� 뿌듯해서 자랑하고 싶었어요�
#
#
# 3 번째 영상의 5 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: qwer 22
# 3.댓글 작성일자: 6개월 전(수정됨)
# 4.댓글 내용: 민스코님은 왜구독자수가 안오를까요ㅠㅠㅠㅜ이렇게 영상이좋은데
#
#
# 3 번째 영상의 6 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: #댓글러
# 3.댓글 작성일자: 6개월 전(수정됨)
# 4.댓글 내용: 저 화장안하는 사람인데 첨부터 끝까지 쭉 봤어요..영상에 마성의 매력이있달까...
#
#
# 3 번째 영상의 7 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 무빙오지는 성하울의
# 3.댓글 작성일자: 7개월 전(수정됨)
# 4.댓글 내용: �타-임-라-인�각질 빠이�� 0:57블렉헤드 빠이�� 2:41올영 파데 추천� 4:13저렴이 파데 브러시� 6:45저렴이 블러셔 브러시� 8:12꾸르템 노다지 웨이크메이크 9:05애교살뿜뿜 12:43페리페라 마스카라 13:42팩보단 이거 14:58
#
#
# 3 번째 영상의 8 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 나유
# 3.댓글 작성일자: 7개월 전(수정됨)
# 4.댓글 내용: 세일이여서 많이 구매했어요�❣좋은템들 소개해주셔서 감사해요
#
#
# 3 번째 영상의 9 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 전현주
# 3.댓글 작성일자: 7개월 전
# 4.댓글 내용: 올리브영 세일이간에 언니가 추천해준거 거의 다사고 왔써여...� 텅장이 되어서 웁니다�
#
#
# 3 번째 영상의 10 번째  댓글
# ----------------------------------------------------------------------
# 1.URL 주소: https://www.youtube.com//watch?v=R5MZ9in3ppA
# 2.댓글 작성자명: 져미
# 3.댓글 작성일자: 7개월 전
# 4.댓글 내용: 와 오늘 메이크업 역대급ㅠㅠㅠ 넘이뻐요... 분위기갑이다ㅜㅜ
#
#
# ====================================================================================================
# 1.요청된 총 3 건 동영상 리뷰 중에서 실제 크롤링 된 리뷰수는 10 건입니다
# 2.총 소요시간은 157.5 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\data\2019-09-04-15-38-38-올리브영\2019-09-04-15-38-38-올리브영.txt
# 4.파일 저장 완료: csv 파일명 : c:\data\2019-09-04-15-38-38-올리브영\2019-09-04-15-38-38-올리브영.csv
# 5.파일 저장 완료: xls 파일명 : c:\data\2019-09-04-15-38-38-올리브영\2019-09-04-15-38-38-올리브영.xls
# ====================================================================================================
