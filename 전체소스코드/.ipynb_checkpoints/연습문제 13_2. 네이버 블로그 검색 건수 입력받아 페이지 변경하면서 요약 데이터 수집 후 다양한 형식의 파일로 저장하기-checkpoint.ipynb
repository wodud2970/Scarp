# %%
# 연습문제 4_1. 네이버 블로그 검색 건수 입력받아 페이지 변경하면서 요약 데이터 수집 후 다양한 형식의 파일로 저장하기

print("=" *100)
print(" 연습문제 13-2: 네이버 블로그 크롤러 : 페이지를 변경하면서 크롤링 후 요약 내용 저장하기")
print("=" *100)

#Step 0. 필요한 모듈과 라이브러리를 로딩하고 검색어를 입력 받습니다

from bs4 import BeautifulSoup
from selenium import webdriver
import time
import sys        # system 설정을 변경하기 위해 필요합니다

# 엑셀 형식과 csv 형식으로 저장하기 위해 표 형태로 데이터를 만들어야 합니다.
# 그렇게 하기 위해 numpy , pandas 패키지를 설치해야 합니다.
import numpy           # cmd 창에서 pip install numpy==1.15.1 로 설치 먼저 하세요
import pandas  as pd    # cmd 창에서 pip install pandas 로 설치 먼저 하세요

# 페이지 번호 계산을 위해 사용합니다
import math    

#필요한 정보를 입력 받습니다
query_txt = input('1.크롤링할 키워드는 무엇입니까?: ')
cnt = int(input('2.크롤링 할 건수는 몇건입니까?: '))
page_cnt = math.ceil(cnt / 10)  # 크롤링 할 페이지 수 

f_name = input('3.txt 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: ')
fc_name = input('4.csv 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: ')
fx_name = input('5.xls 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: ')


#Step 1. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/temp/chromedriver_240/chromedriver.exe"
driver = webdriver.Chrome(path)

driver.get('http://www.naver.com')
time.sleep(2)

s_time = time.time( )     # 검색을 시작하는 시점의 timestamp 를 지정합니다

#Step 2. 네이버 검색창에 입력 받은 검색어를 넣고 검색을 실행합니다
element = driver.find_element_by_id("query")
element.send_keys(query_txt)
element.submit()

#Step 3. 아래의 블로그 링크를 선택합니다
driver.find_element_by_link_text("블로그").click( )


# Step 9. 현재 페이지의 내용을 저장 목록을 만든 후 목록에 있는 내용을 파일에 저장하기

no2=[]           # 게시글 번호 컬럼
title2=[ ]       # 게시글 제목 컬럼
contents2=[ ]    # 게시글 내용 컬럼
intro2=[ ]       # 블로그 소개 컬럼
addr2=[ ]        # 블로그 주소 컬럼

no = 1           # 게시글 번호 초기값

for x in range(1,page_cnt+1) :
    print("\n")
    print("%s 페이지 내용 수집 시작합니다 =======================" %x)
    
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    blog_list = soup.select('ul > li > dl ')

    for i in blog_list:
        
        f = open(f_name, 'a',encoding='UTF-8')

        # 1.게시글 번호
        print("\n")
        no2.append(no)
        f.write("1.번호 :" + str(no) + "\n")
        print("1.번호 : %s" %no)

        # 2. 게시글 제목
        title=i.find('a').get_text()
        title2.append(title)
        f.write("2.제목 :" + str(title) + "\n")
        print("2.제목 : %s" %title)
        
        # 3. 게시글 내용
        contents = i.find('dd','sh_blog_passage').get_text().replace("\n","")                                  
        contents2.append(contents) 
        f.write("3.내용 :" + str(contents) + "\n")
        print("3.내용 : %s" %contents)
        
        # 4. 블로그 소개
        intro = i.find('span','inline').find('a').get_text()
        intro2.append(intro)
        f.write("4.소개 :" + str(intro) + "\n")
        print("4.소개 : %s" %intro)
        
        # 5. 블로그 주소
        addr = i.find('span','inline').find('a')['href']
        addr2.append(addr)
        f.write("5.블로그 주소 :" + str(addr) + "\n")
        f.write("\n")
        print("5.블로그 주소 : %s" %addr)

        f.close( )

        no += 1
        
        if no > cnt :
            break
        
    time.sleep(2)        # 페이지 변경 전 2초 대기 

    x += 1

    if x > page_cnt :
        break
    
    driver.find_element_by_link_text("""%s""" %x).click() # 다음 페이지번호 클릭

# Step 10. 출력 결과를 다양한 형식으로 저장하기

naver_blog = pd.DataFrame()
naver_blog['번호']=no2
naver_blog['제목']=title2
naver_blog['내용']=contents2
naver_blog['블로그소개']=intro2
naver_blog['블로그주소']=addr2

# csv 형태로 저장하기
naver_blog.to_csv(fc_name,encoding="utf-8-sig",index=False)

# 엑셀 형태로 저장하기
naver_blog.to_excel(fx_name,index=False)

e_time = time.time( )     # 검색이 종료된 시점의 timestamp 를 지정합니다
t_time = e_time - s_time

print("\n") 
print("=" *80)
print("크롤링을 요청한 총 %s 건 중에서 %s 건의 데이터를 수집 완료 했습니다" %(cnt,no-1))
print("총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("파일 저장 완료: txt 파일명 : %s " %f_name)
print("파일 저장 완료: csv 파일명 : %s " %fc_name)
print("파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

driver.close( )
# Out:
# ====================================================================================================
#  연습문제 13-2: 네이버 블로그 크롤러 : 페이지를 변경하면서 크롤링 후 요약 내용 저장하기
# ====================================================================================================
# 1.크롤링할 키워드는 무엇입니까?: 여름여행
# 2.크롤링 할 건수는 몇건입니까?: 30
# 3.txt 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: c:\temp\ex_2.txt
# 4.csv 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: c:\temp\ex_2.csv
# 5.xls 형태로 저장할 경로와 파일명을 확장자 포함해서 쓰세요: c:\temp\ex_2.xls
#
#
# 1 페이지 내용 수집 시작합니다 =======================
#
#
# 1.번호 : 1
# 2.제목 : 부산 해동용궁사 몇번을 가도 좋은 국내 여름 여행지
# 3.내용 : 날씨 요정님까지 환영해주셔서 더욱 행복했던 여행이었습니다. 국내에는 부산... 세상일은 우리의 마음이 만든다고 하니 이웃님들께서도 올여름 국내 여름 여행지로...
# 4.소개 : 더많은 세상을 보여줄게
# 5.블로그 주소 : https://blog.naver.com/hp0210
#
#
# 1.번호 : 2
# 2.제목 : <여름여행> 3일차 통영여행 <1박 통영여행 코스>
# 3.내용 : 여름여행 3일차 통영여행 집에서 떠나서 경주 > 부산 > 3일차 통영이다 원래 우리의 계획은 여수 여수의 야경과 케이블카 바다를 생각하고 부산에서 늦은저녁시간 출발...
# 4.소개 : 헬로리지입니다
# 5.블로그 주소 : https://blog.naver.com/rubato1120
#
#
# 1.번호 : 3
# 2.제목 : 제주도 여름여행 쇠소깍
# 3.내용 : 제주도 여름여행 하면 떠오르는 숲과 바다의 풍경을 모두 가지고 있어 여름 제주여행을 할 때는 꼭 생각나는 곳이죠. 사실 제주도 쇠소깍에서 메인은 바다가 아닌 천으로...
# 4.소개 : 오름선생의 제주도여...
# 5.블로그 주소 : https://blog.naver.com/7wayjeju
#
#
# 1.번호 : 4
# 2.제목 : 6월 제주도 2박3일 여행코스 여름여행
# 3.내용 : 6월 제주도 2박3일 여행코스 여름여행 코로나로 인해 올해는 여러가지로 제한적이거나 하지 못하는 경우가 생기게되었습니다. 여행도 마찬가지인데요 여름하면 휴가...
# 4.소개 : 삼춘~ 어드레 감수광...
# 5.블로그 주소 : https://blog.naver.com/junhyuk_abba
#
#
# 1.번호 : 5
# 2.제목 : 제주 여름 여행 비양도,비양봉
# 3.내용 : 제주 섬여행 여름휴가코스로 가볼만한곳 섬속의 섬, 섬안의 섬 비양도입니다.... 제주 여름 여행으로 알차게 계획한다면 이런 재미가 있고 뷰까지 덤으로 얻어갈수 있어...
# 4.소개 : 푸른솔의 작은 여행~
# 5.블로그 주소 : https://blog.naver.com/spa7981
#
#
# 1.번호 : 6
# 2.제목 : 제주도 여름여행 (제주 김만복김밥 본점, 동문시장, 도두후레쉬...
# 3.내용 : 안녕하세요 이웃님들, 이제 여름이고 곧 휴가철도 앞두고 있는데요. 그래서 오늘은... 여행에는 역시 뛰뛰빵빵 차가 좋아욘 ! 제주도 여름여행을 하면서 가장먼저...
# 4.소개 : 그래, 난 포기를 모르는 남...
# 5.블로그 주소 : https://blog.naver.com/gatsbynet
#
#
# 1.번호 : 7
# 2.제목 : 국내 여름 여행지 추천 합천 해인사에서 신비의돌탑까지
# 3.내용 : 여행 일자; 2020년 7월 중순 합천 해인사 소리길 홍류동 계곡 해발 1,430m 가야산... 국내 여름 여행지이다. 여름 더위를 잊을 수 있을 정도로 시원한 계곡 옆으로 데크가 잘...
# 4.소개 : 행복물결 넘실대는 여행이야...
# 5.블로그 주소 : https://nailstan.blog.me
#
#
# 1.번호 : 8
# 2.제목 : 제주도 여름 여행 이호테우해수욕장 일몰, 애월광해
# 3.내용 : 다가온 여름날씨에 곳곳에서는 해자수욕장 개장소식이 많더라구요 저 역시 뻥 뚫린 바다가 보고 싶어 그 김에 스트레스 해소와 아름다운 일몰도 볼 겸 제주도 여름 여행...
# 4.소개 : 동팔이의 즐거운상삶
# 5.블로그 주소 : https://blog.naver.com/happylife_mi
#
#
# 1.번호 : 9
# 2.제목 : 산청 여름여행 남사예담촌 대원사계곡 내원사
# 3.내용 : 1박 2일로 경남 지리산 자락에 위치한 산청 여름여행 남사예담촌 대원사계곡... 걸으니 여름의 정취와 푸르름을 고스란히 느낄 수 있었네요. 여름도 이리도 좋은데 봄...
# 4.소개 : 붕어빵 가족의 담너머 세상...
# 5.블로그 주소 : https://blog.naver.com/1092119
#
#
# 1.번호 : 10
# 2.제목 : 제주 여름여행 비가 오면 나타나는 폭포
# 3.내용 : 제주 여름여행 비가 오면 나타나는 폭포 비 소식이 잦은 제주의 여름! 비가 왔다... 입장료와 주차료는 무료이니 여행 중 가볍게 들러보시길 바라요♪ 엉또폭포 주소...
# 4.소개 : 고르라, 예비사회적...
# 5.블로그 주소 : http://blog.gorra.kr
#
#
# 2 페이지 내용 수집 시작합니다 =======================
#
#
# 1.번호 : 11
# 2.제목 : 제주도 1박2일 코스 여름여행 떠나자
# 3.내용 : 여긴 여름에 야간포차도 개장 한다고 하는데 제주도 여름여행 온다면 또 와야겠어요. 늦게 제주에 도착을해 하루 일정을 소화하려면 일찍 저녁을 먹어야 할 것 같아...
# 4.소개 : 입안의 혀같은 내새...
# 5.블로그 주소 : https://xluxuryx.blog.me
#
#
# 1.번호 : 12
# 2.제목 : 만개한 후라노 팜도미타 보라보라한 세상, 홋카이도 여름 여행
# 3.내용 : 라벤더 만개한 후라노 팜도미타 보라보라한 세상, 홋카이도 여름 여행 솜씨여행... 홋카이도를 여름에 여행한다면 이 멜론을 정말 꼭 먹어보셔야 합니다!!!!!...
# 4.소개 : 솜씨여행 ♡
# 5.블로그 주소 : https://blog.naver.com/somc_travel
#
#
# 1.번호 : 13
# 2.제목 : 국내 여름 여행지 추천 경주 플록스 꽃잔치~
# 3.내용 : 국내 여름 여행지 경주를 추천하는 것은 사실 더위와 싸워야하는 일인데요. 이열치열이라고 여름 더위를 제대로 느끼면서 꽃향기에 훅 안길 수 있는 여행지, 바로 첨성대...
# 4.소개 : ♥마리안의 여행이야기-마음...
# 5.블로그 주소 : https://anndam.blog.me
#
#
# 1.번호 : 14
# 2.제목 : 제주도 여름여행 산수국 숲길 코스 족은노꼬메 상잣성길
# 3.내용 : 7월2일에 다녀온 제주도 여름여행 코스로 좋은 산수국이 절정인 숲길 비밀의숲과... 제주도 여름여행으로도 좋은 숲길입니다 나무에 낀 이끼 마저도 예쁜 곳 지금부터는...
# 4.소개 : 유니크의 제주살이
# 5.블로그 주소 : https://blog.naver.com/9unique
#
#
# 1.번호 : 15
# 2.제목 : 지리산호수공원과 피아골계곡에서 즐기는 비대면 힐링 여름 여행
# 3.내용 : 피해 여름여행을 계획하시는 분들이 많을텐데요. 올해는 코로나19의 확산으로 여행지를 선택할 때에도 신중해야만 합니다. 올 여름, 비대면 여행을 원하신다면 구례...
# 4.소개 : 전라남도 공식 블로그-남도...
# 5.블로그 주소 : https://blog.naver.com/greenjeonnam
#
#
# 1.번호 : 16
# 2.제목 : 부산 여름여행 해운대 시장 구경
# 3.내용 : 여름 시즌에는밤이 되면 문화광장에서 유명한 분수쇼도 즐길 수 있어요 화려한 음악에 맞춰 분수가 나오는데 한번 보기 시작하면 끝까지 보게된답니다 부산 여름여행...
# 4.소개 : 백령도해병 여행기록보관소
# 5.블로그 주소 : https://blog.naver.com/taekwon4820
#
#
# 1.번호 : 17
# 2.제목 : 대원사 계곡길 산청 여름 여행 지리산 계곡 가자~
# 3.내용 : 산청 여름 여행~ 시원하다 못해 차가운 계곡물은 대원사 계곡만큼 좋은 곳은 없을 겁니다. 저는 대원사, 내원사, 정각사 등등 중산리 지리산 계곡은 여름휴가를 이용해...
# 4.소개 : 지지나라 (천연,건강,여행,...
# 5.블로그 주소 : https://blog.naver.com/zizinara1004
#
#
# 1.번호 : 18
# 2.제목 : 국내 여행코스 여수 1박2일 여름여행
# 3.내용 : 1박2일 여름여행 낭만과 힐링이 있는 여수를 다녀왔습니다. 동네 근처나 가까운 지역을 다니다가 간만에 1박2일 여행이라 약간의 설레임도 있었구요 이번엔 여름과...
# 4.소개 : 삼춘~ 어드레 감수광...
# 5.블로그 주소 : https://blog.naver.com/junhyuk_abba
#
#
# 1.번호 : 19
# 2.제목 : 국내 여름 여행지 시원한 고수동굴
# 3.내용 : 국내 여름 여행지 시원한 동굴여행 고수동굴에 다녀왔습니다. 더운 여름이 이어지고 있는데요 시원한 휴가지 없을까 고민하다 보니 이곳만큼 좋은 곳이...
# 4.소개 : 청개구리 체험 여행
# 5.블로그 주소 : https://blog.naver.com/dirch10
#
#
# 1.번호 : 20
# 2.제목 : 제주도 여름여행 필수코스 마노르블랑 유럽수국축제
# 3.내용 : 일상에서 하루쯤 아니 한나절쯤은 여행 모드로 전환해보면 삶이 더 반짝반짝 ... 제주도 여름여행 필수코스 마노르블랑 유럽수국축제 다녀오면서 가족들과 다시 가보고...
# 4.소개 : 제주이야기꾼의 책 & 여행
# 5.블로그 주소 : https://blog.naver.com/logenjjem
#
#
# 3 페이지 내용 수집 시작합니다 =======================
#
#
# 1.번호 : 21
# 2.제목 : 태안 안면도 1박2일 여름여행코스
# 3.내용 : 근처 여행계획이 있다면 참고하시어 여름휴가나 여름여행코스로 계획하면 좋겠습니다 태안 솔향기길 1코스가 위치한 길에는 숨어있는 보석같은 펜션이 있는데 바로...
# 4.소개 : 푸른솔의 작은 여행~
# 5.블로그 주소 : https://blog.naver.com/spa7981
#
#
# 1.번호 : 22
# 2.제목 : 강원도 여름 여행 인생샷도 남기고, 재미있게 놀고 싶다면?
# 3.내용 : 다들 여름 여행 어떻게 준비중이신가요? 저는 이번에 남자친구하고 같이 조금 이른 강원도 여름 여행을 다녀왔어요~ 여러가지 가볼만한 곳들은 죄다 다녀왔던 거...
# 4.소개 : 서버를 찾지 못하였습니다.
# 5.블로그 주소 : https://blog.naver.com/trusia_01b
#
#
# 1.번호 : 23
# 2.제목 : 함께 김해가야테마파크와 장유대청계곡으로 떠나는 여름여행
# 3.내용 : 이번 여름 여행계획을 세워보자. 이번에 살펴볼 김해가야테마파크와... "어떠한 지원도 받지 않았으며 여행정보를 제공하기 위해 작성한 글입니다" "내용에 오류가 있을...
# 4.소개 : 올려다보면 하늘 내...
# 5.블로그 주소 : http://withbeatles.tistory.com/
#
#
# 1.번호 : 24
# 2.제목 : 산청 여름여행 경남 지리산 대원사계곡길 내원사 황매산
# 3.내용 : 지리산절 #비로자나불 #지리산내원사삼층석탑 #지리산천왕봉 #산청트릭아트 #황매산 #산청황매산 #산청군 #산청황매산미리내파크 #산청오토캠핑장 #산청여행 #여름여행
# 4.소개 : 맛있는 건 언제나 옳아
# 5.블로그 주소 : https://blog.naver.com/sajapyung
#
#
# 1.번호 : 25
# 2.제목 : 아침고요수목원 국내 여름 여행지
# 3.내용 : 여름 힐링 명소로 당일치기 드라이브 여행하기 좋은 아침고요수목원 여름을 만나고... 함께 즐거운 여름의 추억도 만들 수 있는 아주 유익한 당일치기 여름 여행지였습니다.
# 4.소개 : 일상탈출
# 5.블로그 주소 : https://blog.naver.com/tcacyc
#
#
# 1.번호 : 26
# 2.제목 : 가평 빠지 행복했던 우리들의 짧은 여름여행
# 3.내용 : 다음에 기회가 되면 다시 한 번 또 가고싶다 ㅠㅠ 올해는 정말 친구들이랑 1박2일 여행도 못 가보는... 슬프닥 코로나가 느므 미울뿐... ㅠㅠ 가평 빠지 여름여행 안녕....
# 4.소개 : 네가족의 솔직 담백한 이야...
# 5.블로그 주소 : https://blog.naver.com/evesove717
#
#
# 1.번호 : 27
# 2.제목 : 간사이 여름 여행, 초보자부터 경험자까지~ <간사이 여름여행...
# 3.내용 : 아쉬운 마음에 준비한 간사이 여름 여행 추천지, 간사이 여행 초보자부터 중급자 이상 레벨까지 고루고루 준비해봤어요~ 여름엔 역시 바다! <고베> 여름이면 역시...
# 4.소개 : 한큐한신 공식블로그...
# 5.블로그 주소 : https://blog.naver.com/gokansai
#
#
# 1.번호 : 28
# 2.제목 : 국내 여름 여행지 추천 경주 황성공원 맥문동~
# 3.내용 : 많아 몸과 마음까지 힐링 되는 곳이었어요. 8월 국내 여름 여행지 추천 장소로 찾아보면 예쁜 보랏빛 맥문동 꽃과 함께 볼 수 있을 것 같습니다.^^ 여행일 2020년 5월 말
# 4.소개 : 국가대표의 여행일기
# 5.블로그 주소 : https://blog.naver.com/suk4408
#
#
# 1.번호 : 29
# 2.제목 : 여수 여름여행 코스 추천! 다시 찾고 싶은 낭만 가득 여행지~
# 3.내용 : 2020 여름 팸투어, 다시 찾고 싶은 여수 우리, 함께!(1탄) 여수 여름여행 코스 추천! 낭만 가득 여행지 안녕하세요, 힐링여수야 입니다! 지난주 금요일 부터 토요일까지...
# 4.소개 : 여수관광 공식 블로...
# 5.블로그 주소 : https://blog.naver.com/goystour
#
#
# 1.번호 : 30
# 2.제목 : 국내 여름 여행지 여수밤바다 보러 여수케이블카 타기
# 3.내용 : 국내 여름 여행지 여수밤바다 보러 여수케이블카 타기 조카들과 오랜만에... 여수 밤바다도 보고 아이들이 좋아하는 케이블카도 타고 왔던 여수 당일치기 여행 마지막...
# 4.소개 : 직딩의 여행서 ♬
# 5.블로그 주소 : https://blog.naver.com/wlsrud1318
#
#
# ================================================================================
# 크롤링을 요청한 총 30 건 중에서 30 건의 데이터를 수집 완료 했습니다
# 총 소요시간은 11.9 초 입니다
# 파일 저장 완료: txt 파일명 : c:\temp\ex_2.txt
# 파일 저장 완료: csv 파일명 : c:\temp\ex_2.csv
# 파일 저장 완료: xls 파일명 : c:\temp\ex_2.xls
# ================================================================================
