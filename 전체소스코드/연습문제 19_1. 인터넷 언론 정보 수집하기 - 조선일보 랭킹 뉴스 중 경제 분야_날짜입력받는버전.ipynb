# %%
# 인터넷 언론 정보 수집하기 - 조선일보 랭킹 뉴스 중 경제 분야 - 조회 날짜 지정하기

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.

from bs4 import BeautifulSoup
from selenium import webdriver
import urllib.request
import time
import sys
import re
import math
import numpy  
import pandas as pd  
import xlwt
import random
import os

#Step 2. 사용자에게 검색어 키워드를 입력 받습니다.
print("=" *80)
print(" 인터넷 언론 정보 수집하기 - 조선일보 랭킹 뉴스중 경제 분야")
print("=" *80)
print("\n")

#url = 'http://news.chosun.com/ranking/list.html?type=&site=www&scode=politics&term=&date=' #정치분야 url
#url = 'http://news.chosun.com/ranking/list.html?site=www&scode=national&date='  # 사회분야 url
url = 'http://news.chosun.com/ranking/list.html?site=chosunbiz&scode=index&date=' # 경제분야 url

st_date = input('1.조회 시작일을 입력하세요(예:20160101) :  ')
en_date = input('2.조회 종료일을 입력하세요(예:20161231) :  ')

f_dir=input('3.파일이 저장될 경로만 쓰세요;(예:c:\\temp\\): ')

now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)
  
os.makedirs(f_dir+'조선일보_경제뉴스'+'-'+s)
os.chdir(f_dir+'조선일보_경제뉴스'+'-'+s)

ff_name=f_dir+'조선일보_경제뉴스'+'-'+s+'\\'+'조선일보_경제뉴스'+'-'+s+'.txt'

#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.

s_time = time.time( )

path = "c:/temp/chromedriver_240/chromedriver.exe"
driver = webdriver.Chrome(path)

#Step 4. 날짜 계산하기

s_year=st_date[0:4]
e_year= en_date[0:4]
mon=["01","02","03","04","05","06","07","08","09","10","11","12"]
i=0

start_date2=[]
end_date2=[]

for i in range(0,len(mon)) :
    if mon[i] =="02" :
        sdate=s_year+mon[i]+'01'
        start_date2.append(sdate)
  
        edate=e_year+mon[i]+'28'
        end_date=edate
        end_date2.append(end_date)
    
    elif mon[i] == "04" or mon[i]=="06" or mon[i]=="09" or mon[i]=="11" :
        sdate=s_year+mon[i]+'01'
        start_date2.append(sdate)
    
        edate=e_year+mon[i]+'30'
        end_date=edate
        end_date2.append(end_date)
    else :
        sdate=s_year+mon[i]+'01'
        start_date2.append(sdate)
    
        edate=e_year+mon[i]+'31'
        end_date=edate
        end_date2.append(end_date)

#Step 5. 각 날짜별 기사의 Title 을 추출합니다.

total_count = 0

for x in range(0,len(end_date2)) :

    for i in range(int(start_date2[x]),int(end_date2[x])) :
        full_url = url+str(i)
  
        driver.get(full_url)
        time.sleep(2)

        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
    
        count = 0
        news_no = 1
        c_year=str(i)[0:4]
        c_mon=str(i)[4:6]
        c_day=str(i)[6:]
        
        article_result = soup.find('div', class_='list_content rank_numbering')
        ar_list = article_result.find_all('dl')
        print("\n")
        print("%s년 %s월 %s일의 뉴스 수집 중 ===================================" %(c_year,c_mon,c_day))
        
        f = open(ff_name, 'a',encoding='UTF-8')
        f.write("%s년 %s월 %s일의 뉴스 수집 중 =================================" %(c_year,c_mon,c_day))
        f.write("\n")
        
        for li in ar_list:        
            title = li.find('div','list_inner').find('dt').get_text()
            print(news_no,": ",title)
            
            f.write(str(news_no) + ": " + title + "\n")        
            time.sleep(0.2)
                        
            count += 1
            news_no += 1
            
        f.write("%s 건  완료=====================================================" % count + "\n")
        f.write("\n")
        f.close( )
                    
        print("%s 건  완료========================================================" % count)
        
        total_count += count
        print("현재까지 총 %s 건의 기사를 수집 완료 했습니다" %total_count)
        print("\n")
        time.sleep(1)
  

        if str(i) == en_date :
            break
            
    if str(i) == en_date :
            break
    

#Step 8. 출력 결과를 파일에 저장하기

e_time = time.time( )
t_time = e_time - s_time


print("총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("총 저장 건수는 %s 건 입니다 " %total_count)
print("txt 파일 저장 완료: 파일명 : %s " %ff_name)

driver.close( )
# Out:
# ================================================================================
#  인터넷 언론 정보 수집하기 - 조선일보 랭킹 뉴스중 경제 분야
# ================================================================================
#
#
# 1.조회 시작일을 입력하세요(예:20160101) :  2019-01-01
# 2.조회 종료일을 입력하세요(예:20161231) :  2019-01-10
# 3.파일이 저장될 경로만 쓰세요;(예:c:\temp\): c:\data\
#
#
# 2019년 01월 01일의 뉴스 수집 중 ===================================
# 1 :  반도체 수출만 1000억달러…韓 세계 7번째로 수출 6000억달러 돌파(종합)
# 2 :  남는 세수로 빚 갚아왔는데… 2017년 11월, 기재부선 무슨 일이
# 3 :  증권사 리서치센터장이 뽑은 새해 유망주식 5개
# 4 :  [2019 신차]① 벤츠 '더 뉴 A클래스'...크고 스마트해졌다
# 5 :  [新페이 인류]① 류영준 카카오페이 "국내엔 경쟁사 없어…100만 가맹점 목표"
# 6 :  [비즈톡톡] ‘순혈주의’ 못 깬 남양...5년째 불매운동에도 변화 거부
# 7 :  손태승 우리은행장 "최고의 은행 되기 위해 끊임없이 노력해야"
# 8 :  GTX 착공에 부푸는 건설업계 토목 수주 기대감
# 9 :  한국GM, 주요 차종 가격 인하…이쿼녹스 최대 300만원 낮춰
# 10 :  '왕영은 타임'을 아시나요
# 11 :  태양계 비밀 간직한 '타임캡슐' 만난다
# 12 :  [구광모의 뉴LG]② ‘은밀하고 착실하게’ 12년간 경영수업
# 13 :  [구광모의 뉴LG]① 베일 속 후계자 '4세 경영 시대'를 열다
# 14 :  정부, 자영업자 3년간 2조원 채무감면...5만7000명 구제 계획
# 15 :  [2019 신년사] 권평오 코트라 사장 "올해 수출 6000억달러 돌파 전망”
# 16 :  강원 속초·경북 경산 미분양관리지역 새로 선정…전국 35곳
# 17 :  고객사 “D램 가격 10% 내려라”…韓 반도체 '진짜 겨울'
# 18 :  오피스텔 기준시가 7.5% 올라… 최고가는 롯데월드타워
# 19 :  수출 최대 호황에도… 고꾸라진 경제 성적표
# 20 :  기재부 “靑 적자국채 4조 발행 압박 의혹, 사실과 다르다”
# 21 :  아동수당 모든 만6세 미만에 지급…기초연금 최대 30만원
# 22 :  [자율車 골드러시]① 자율주행차 뇌를 만들다...한국계 스타트업 '팬텀 AI'
# 23 :  아이 울음소리 끊긴 제일병원, 1월 회생절차 밟나
# 24 :  트럼프發 '역풍'에 대미 무역흑자 6년 만에 최소
# 25 :  여의도·용산·마포 등 서울 도심 8곳, 주거비율 90%로 상향
# 26 :  "최저임금법 현실 반영 못해"…초봉 5000만원 대기업도 위반 속출할듯
# 27 :  돼지띠 CEO들 "올해는 나의 해"
# 28 :  스타워즈 키즈, 360조원 우주 시장으로 '출격'
# 29 :  개성공단 입주기업 "北 개성공단 재개 의지 환영"
# 30 :  화웨이, 3분기 프리미엄폰 점유율 10% 넘어…글로벌 출하 2억대 넘겨
# 30 건  완료========================================================
# 현재까지 총 30 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 02일의 뉴스 수집 중 ===================================
# 1 :  '계절밥상' 11곳 폐점… 새해 첫날 알바 200명 일자리 잃어
# 2 :  값 올리든지, 직원 자르든지, 아니면 문닫든지… 골목가게의 한숨
# 3 :  신재민 전 사무관 "차영환 전 靑 비서관 적자국채 강요"
# 4 :  [팩트 체크] 3.5%→2.8%→2.5%, 갈수록 추락하는데 "소비는 좋다"니…
# 5 :  현대차, 걸어다니는 車 ‘엘리베이트’ 콘셉트카 티저이미지 공개
# 6 :  국채발행 압력 의혹 靑 인사 차영환은 누구
# 7 :  뉴욕 부동산도 공급 앞에 장사없더라
# 8 :  국수 맛집 사장 "최저임금 너무나 가혹"
# 9 :  [2019 신년사] 차석용 LG생건 부회장 "보석같은 회사 만들어나가자"
# 10 :  [2019 신차]② 폴크스바겐 3세대 투아렉...안전·주행성능 혁신
# 11 :  "공급 앞에 장사 없어"…송파 매매∙전세 동반하락
# 12 :  유튜브, 동영상 앱 점유율 86%… 압도적 1위
# 13 :  국민연금 비정규직 1231명 전원 정규직 전환
# 14 :  돌돌 말리는 65인치, 4배 더 선명한 98인치 TV
# 15 :  반도체 생산·수출 급감…올해 성장률 2% 중반도 ‘흔들'
# 16 :  남는 세수로 빚 갚아왔는데… 2017년 11월, 기재부선 무슨 일이
# 17 :  현대·기아차, 지난해 739만8975대 판매…4년째 목표달성 실패
# 18 :  '신세계'서 '롯데'로 간판 바꾼 인천터미널 백화점
# 19 :  쪼그라든 서울 주택거래…올해 전망도 '먹구름'
# 20 :  [구광모의 뉴LG]④ 로봇·車·인공지능...미래 사업 육성
# 21 :  유튜브·넷플릭스에 밀렸던 유료방송업계...기해년에는 황금돼지 잡을까
# 22 :  [2019 신년사] 서경배 아모레 회장 "변화는 혁신의 기회"
# 23 :  [구광모의 뉴LG]② ‘은밀하고 착실하게’ 12년간 경영수업
# 24 :  증권사 리서치센터장이 뽑은 새해 유망주식 5개
# 25 :  [김기천 칼럼] 새해 경제, 반전(反轉)의 희망
# 26 :  [초고령사회 유럽을 가다]② 동네 의사가 주치의...1차진료로 뇌졸중 사망 줄여
# 27 :  [2019 신년사] 조원태 대한항공 사장 “감사와 소통으로 새로운 100년을”
# 28 :  [가상 유튜버가 온다]① 日열도 강타한 키즈나 아이, 아이돌 뛰어넘는 인기
# 29 :  신년사로 본 재계 기해년 생존법…혁신·변화·고객
# 30 :  [2019 신차]① 벤츠 '더 뉴 A클래스'...크고 스마트해졌다
# 30 건  완료========================================================
# 현재까지 총 60 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 03일의 뉴스 수집 중 ===================================
# 1 :  100억 주식 부자서 빚쟁이로… 텅 빈 사무실이 날 깨웠다
# 2 :  홍남기 "신재민 전 사무관 무사해 눈물이 날 지경"
# 3 :  이재용 부회장, 5G 가동식 참석…"도전자 자세로 경쟁력 키워야"
# 4 :  [스타벅스 경영]④ 시끄럽지만 공부 잘되는 '공간'의 비밀
# 5 :  불황 바닥 울산서도 오른 단독주택…올해도 뜨거울까?
# 6 :  "청약통장이 움직인다"…상반기 서울 '로또 단지' 3.3만가구
# 7 :  실큰 2년연속 배우 홍은희 모델계약 채결
# 8 :  주휴수당 피하려 알바쪼개기..."투잡 뛰어야 할판"
# 9 :  이마트, 전복·삼겹살 990원에 판매
# 10 :  신재민 전 사무관 "차영환 전 靑 비서관 적자국채 강요"
# 11 :  '계절밥상' 11곳 폐점… 새해 첫날 알바 200명 일자리 잃어
# 12 :  국채발행 압력 의혹 靑 인사 차영환은 누구
# 13 :  2년 연속 대통령 불참한 경제계 신년인사회
# 14 :  자금난 겪던 이랜드 '박성수·박성경' 남매경영 손떼는 속내는
# 15 :  文, 경제계 신년회 2년째 불참… 재계 "기업인에 대한 시각 반영"
# 16 :  현대차, 걸어다니는 車 ‘엘리베이트’ 콘셉트카 티저이미지 공개
# 17 :  [마켓뷰] 팀 쿡 편지에 2000선 깨진 코스피…반도체주도 줄이어 하락
# 18 :  코스피지수 기관·외인 매도에 2000선 붕괴
# 19 :  車가 운전자 감정 살핀다…기아차, CES에서 ‘감정반응 제어시스템’ 공개
# 20 :  최저임금發 '무인화' 확산… 만남의광장 주유소도 셀프로
# 21 :  中企중앙회로 4대그룹 총수 불러놓고 "함께 잘사는 나라로"
# 22 :  [2019 신차]③ BMW 4세대 X5...강렬한 디자인
# 23 :  기업공개 시장 '황금돼지' 몰려온다
# 24 :  신재민 사태에 입 연 김동연 前 부총리 "전체 봐야 하는 입장 생각해달라"
# 25 :  삼성重, 세계 최대 에지나 FPSO 첫 원유생산 성공
# 26 :  [팀장칼럼] 연말마다 반복되는 개인의 오락가락 매매
# 27 :  값 올리든지, 직원 자르든지, 아니면 문닫든지… 골목가게의 한숨
# 28 :  "공급 앞에 장사 없어"…송파 매매∙전세 동반하락
# 29 :  [안재만의 투자노트] 화장품, 너마저
# 30 :  산업부 "태양광 발전, 토지 이용 최소화" 화두 꺼냈다
# 30 건  완료========================================================
# 현재까지 총 90 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 04일의 뉴스 수집 중 ===================================
# 1 :  "공시지가 2배 인상, 정부가 지침 내렸다"
# 2 :  신재민 사태에 입 연 김동연 前 부총리 "전체 봐야 하는 입장 생각해달라"
# 3 :  암(癌)분야 세계적 석학 홍완기 박사 미국 자택서 별세
# 4 :  집값 과열 '낌새'만 보여도 진화… 수원·용인 청약조정지역 지정
# 5 :  CJ·신세계, 빕스·올반 고객 줄어 문 닫으며 '최저임금' 탓
# 6 :  자율규약·미니스톱·노브랜드까지...이마트24 '삼중고'
# 7 :  [특징주] 삼성전자 아니고 二성전자?…우선주, 2만원대로 하락
# 8 :  화장품 로드숍 죽쑤는데...한국콜마·코스맥스 매출 1兆 비결은
# 9 :  [초고령사회 유럽을 가다]④ IT로 복지기술 투자...암환자도 집에서 치료받아
# 10 :  "정부, 강남·중구 담당 민간평가사에 따로 지침내려"
# 11 :  자금난 겪던 이랜드 '박성수·박성경' 남매경영 손떼는 속내는
# 12 :  지난해 수입차 시장 ‘벤츠 독주’…E클래스 앞세워 판매 7만대 돌파
# 13 :  홍남기 "신재민 전 사무관 무사해 눈물이 날 지경"
# 14 :  홍남기 "1월중 최저임금 결정구조 개편 정부안 확정…다음주 초안발표"
# 15 :  매물로 나온 게임 대표기업 넥슨, 중국으로 팔려가나
# 16 :  130 대 1
# 17 :  국민은행 경영진 일괄 사표 제출…"파업시 책임지겠다"
# 18 :  '적자국채 추가발행 의혹'에 홍남기 부총리 반박…"외압 없었다"
# 19 :  [조회답변] 셀트리온 "제3공장 국내에 건설할 것"
# 20 :  [2019 신차] 아우디 2세대 A7, 버튼 하나로 자동 주차까지
# 21 :  223대1 '바늘구멍'…"그래도 특별공급"
# 22 :  이재용 부회장 "4차 산업혁명 시대 반도체 시장 창조"
# 23 :  車가 운전자 감정 살핀다…기아차, CES에서 ‘감정반응 제어시스템’ 공개
# 24 :  "당분간 인내심 필요…똘똘한 개별종목 찾아라"
# 25 :  "청약통장이 움직인다"…상반기 서울 '로또 단지' 3.3만가구
# 26 :  김정주 NXC 대표 "여러 방안 놓고 숙고 중"
# 27 :  80억짜리 거래소 ‘인공지능 감시 시스템’ 실효성 논란
# 28 :  [2019 신차]③ BMW 4세대 X5...강렬한 디자인
# 29 :  강릉 펜션 사고 예방하려면…"근본 대책은 보일러 센서 기술"
# 30 :  5G 요금 LTE보다 비싸지나…"1만원 인상 vs 못 올린다"
# 30 건  완료========================================================
# 현재까지 총 120 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 05일의 뉴스 수집 중 ===================================
# 1 :  [이코노미조선] 일곱 번째 LCC탄생...치열해지는 하늘길 경쟁
# 2 :  중국·인도·브라질… 주춤했던 原電건설 다시 속도낸다
# 3 :  [이코노미조선] [Interview] 짐 로저스 “암호화폐는 결국 사라질 것”
# 4 :  국토부 "공시價 개입은 정당 권한"… 법조계 "재량권 넘어선 직권남용"
# 5 :  CJ·신세계, 빕스·올반 고객 줄어 문 닫으며 '최저임금' 탓
# 6 :  [헬스TALK] 새해에 다이어트 결심했다면…체지방률 먼저 확인
# 7 :  [초고령사회 유럽을 가다]⑤ 한국형 커뮤니티케어, 제대로 하려면 환자 정보 공유 먼저
# 8 :  암(癌)분야 세계적 석학 홍완기 박사 미국 자택서 별세
# 9 :  커지는 글로벌 경기둔화 우려…다시 고개 드는 '저물가' 공포
# 10 :  외환보유액 4036억달러… 사상최대 기록
# 11 :  이재용 부회장 "4차 산업혁명 시대 반도체 시장 창조"
# 12 :  "집창촌에서 복합 주거단지로"…청량리 새해 첫 '강북 로또' 기대
# 13 :  "공시지가 2배 인상, 정부가 지침 내렸다"
# 14 :  [비즈 톡톡] 광고업계가 ‘퀸’ 음악 애용하는 이유
# 15 :  IT에서 金으로…재테크 효자가 바뀌었다
# 16 :  [이코노미조선] 디즈니, 넷플릭스에 선전포고…韓 콘텐츠 반사이익
# 17 :  223대1 '바늘구멍'…"그래도 특별공급"
# 18 :  [2019 신차] 아우디 2세대 A7, 버튼 하나로 자동 주차까지
# 19 :  경기 침체와 구조 변화…“中에 내구재 파는 시대 저물어 가”
# 20 :  [2019 신차]③ BMW 4세대 X5...강렬한 디자인
# 21 :  김정주 NXC 대표 "여러 방안 놓고 숙고 중"
# 22 :  삼성전자 올해 스마트폰 사업전략은 "사용자 경험 강화"
# 23 :  코스피 상장기업 영업이익 올 188兆 전망… 반년새 31조원 깎여
# 24 :  국민은행 경영진 일괄 사표 제출…"파업시 책임지겠다"
# 25 :  車가 걸어다니고 인간과 소통까지…2019 CES에서 펼쳐질 미래차 新기술
# 26 :  화장품 로드숍 죽쑤는데...한국콜마·코스맥스 매출 1兆 비결은
# 27 :  산업은행, 동부제철 매각 나선다
# 28 :  강릉 펜션 사고 예방하려면…"근본 대책은 보일러 센서 기술"
# 29 :  국회 ‘임세원법’ 발의…유족 조의금 기부 의사
# 30 :  "당분간 인내심 필요…똘똘한 개별종목 찾아라"
# 30 건  완료========================================================
# 현재까지 총 150 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 06일의 뉴스 수집 중 ===================================
# 1 :  청년일자리, 뒷걸음질…20대 고용률, 글로벌 금융위기 때보다 낮아
# 2 :  "초과세수는 '보너스' 아니다"...'신재민 vs.김동연', 경제전문가들 판단은?
# 3 :  롯데百, 해외명품대전 진행...프리미엄패딩 최고 70% 할인
# 4 :  시중은행, 연말연시 잇따라 희망퇴직 실시
# 5 :  "장바구니 없이 장봐요"...롯데마트 인천터미널점 개점
# 6 :  [이코노미조선] 사상 최대 실적 도요타, 임원 수 절반 줄인 파격 조직 개편
# 7 :  서정진 회장 "셀트리온-셀트리온헬스케어 합병은 주주 뜻대로"
# 8 :  [단독] 금감원, 보험사기 온상 요양병원 실태조사 착수
# 9 :  CJ·신세계, 빕스·올반 고객 줄어 문 닫으며 '최저임금' 탓
# 10 :  서정진 셀트리온 회장 “팔팔할 때 은퇴"...2020년말 전문경영인 체제 예고
# 11 :  [이코노미조선] 일곱 번째 LCC탄생...치열해지는 하늘길 경쟁
# 12 :  기아차, 노후 경유차 신차로 교체시 최대 40만원 지원
# 13 :  "카본 유모차로 세계 시장서 우뚝 서겠다"...정세훈 쁘레베베 대표
# 14 :  이재용 부회장 "4차 산업혁명 시대 반도체 시장 창조"
# 15 :  대기업, 또 글로벌 헤지펀드 먹잇감 되나…상륙說 '모락모락'
# 16 :  팬스타그룹, 부산 청년일자리 창출 나서
# 17 :  국민銀, 총파업 D-2...8일 거점점포 운영 검토
# 18 :  커지는 글로벌 경기둔화 우려…다시 고개 드는 '저물가' 공포
# 19 :  네이버·카카오, 캐릭터로 차세대 '韓流' 이끈다
# 20 :  포스코, 리튬공장 생산규모 33% 확대
# 21 :  편의점‧슈퍼마켓 “1분기 수익성 악화 예상”
# 22 :  223대1 '바늘구멍'…"그래도 특별공급"
# 23 :  [헬스TALK] 새해에 다이어트 결심했다면…체지방률 먼저 확인
# 24 :  롯데免 명동점, 지난해 매출 4조원...'세계1위'
# 25 :  갤러리아百, 미국 유명브랜드와 협업해 텀블러 출시
# 26 :  [2019 신차] 아우디 2세대 A7, 버튼 하나로 자동 주차까지
# 27 :  [이코노미조선] [Interview] 짐 로저스 “암호화폐는 결국 사라질 것”
# 28 :  "집창촌에서 복합 주거단지로"…청량리 새해 첫 '강북 로또' 기대
# 29 :  정기선 현대중공업 부사장, CES 첫 참관
# 30 :  월 소득 512만원 이하 부부도 올해부터 난임시술비 지원
# 30 건  완료========================================================
# 현재까지 총 180 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 07일의 뉴스 수집 중 ===================================
# 1 :  '5無'가 뜬다...2019년 유통 트렌드는
# 2 :  [인터뷰] 정신아 카카오벤처스 대표 “꼰대 안 되는 게 목표죠”
# 3 :  "초과세수는 '보너스' 아니다"...'신재민 vs.김동연', 경제전문가들 판단은?
# 4 :  [세법 시행령] 월급 210만원 이하 근로자는 야근수당 비과세
# 5 :  내년 최저임금, 전문가가 인상폭 정하면 노·사·정이 확정
# 6 :  청년일자리, 뒷걸음질…20대 고용률, 글로벌 금융위기 때보다 낮아
# 7 :  [CES 2019] 최대 규모 전시관 꾸린 삼성, 뉴빅스비·5G 등 신기술 공개
# 8 :  "신도시∙인프라 덕 좀 보나"…건설업계 '황금돼지꿈'
# 9 :  애플 아이튠즈가 삼성 TV 속으로...특허분쟁 중인 삼성전자·애플 협업
# 10 :  [CES 2019] 삼성전자, 세계 최소형 75인치 마이크로LED TV 공개
# 11 :  이마트서 물건 사면 자율주행차가 당일 배송
# 12 :  현대차, 월 구독형 서비스 ‘현대 셀렉션’ 출시
# 13 :  국민은행 노조 "협상 결렬"…19년 만에 총파업 현실화
# 14 :  현대종합상사, 현대重에 ‘현대’ 해외 상표권 매각 후 재임차
# 15 :  은행, 가계·중기 대출문턱 더 높인다
# 16 :  그렇게 홍보했건만… 자영업 전체 '제로페이 효과' 116만원
# 17 :  '비둘기가 된 파월'…원·달러 환율 급락
# 18 :  농협 하나로 '갑질'...200일 지난 생선 반품, 허위 매출, 고위직 낙하산
# 19 :  중국도 일본도 미국도… 세계는 수소차 각축전
# 20 :  CJ·신세계, 빕스·올반 고객 줄어 문 닫으며 '최저임금' 탓
# 21 :  국민은행 총파업 D-1, 마라톤 협상에도 합의점 못 찾아
# 22 :  [안재만의 투자노트] 美금리 인하? 파월이 한번 봐준 것 같은데
# 23 :  LS전선, 대만에 해저케이블 공급…국내 최초
# 24 :  "앞으로는, 판교 위에 왕숙 있다"
# 25 :  올해 불붙는 도시정비사업 격전지는 어디?
# 26 :  편의점‧슈퍼마켓 “1분기 수익성 악화 예상”
# 27 :  최저임금 ‘16.4% 인상 쇼크’ 재연 없앤다
# 28 :  한투, 불법대출 논란…초대형IB 운명의 날 D-3
# 29 :  민주노총 "한수원 특수경비 정규직 전환하라"
# 30 :  반도체·가전·스마트폰 모두 먹구름…삼성·LG전자, 실적 하향조정
# 30 건  완료========================================================
# 현재까지 총 210 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 08일의 뉴스 수집 중 ===================================
# 1 :  [2019 CES] 현대차, 걸어다니는 車 ‘엘리베이트’ 콘셉트카 공개
# 2 :  '모난' 강남 아파트, 추락 땐 '억소리'
# 3 :  [단독] 돼지 수천마리 몰래 판 사조동아원, 美 카길에 패소
# 4 :  삼성전자, 4분기 '어닝쇼크'에 빛바랜 사상 최대 연간 실적(종합)
# 5 :  삼성전자 '어닝쇼크' 4분기 영업익 38% '뚝'
# 6 :  이미 29% 올랐는데… 최저임금 개편안, 깨진 독에 물붓기
# 7 :  '효리네 민박' 덕분에 제주 관광객 100만명 증가
# 8 :  [CES 2019] 삼성, 5G 스마트폰 상반기 출시…8K TV에 AI 담고 로봇도 선봬
# 9 :  믿었던 가전·TV마저 흔들…LG전자, 올해도 쉽지 않을 듯
# 10 :  신동주, 출소한 신동빈에 화해 편지...롯데 "진정성 없다"
# 11 :  구직자 늘어나는 미국, 182만명 '그냥 쉬는' 한국
# 12 :  3000만원 대출 퇴짜 맞은 청년, 지금 1600억 움직입니다
# 13 :  LG전자 지난해 사상 최대 연간 실적...4분기만 보면 '빨간불'(종합)
# 14 :  "소규모 주택 재건축이 아파트보다 쉬워요"
# 15 :  '반도체發 수출' 주춤하니…반토막 난 경상흑자
# 16 :  '5無'가 뜬다...2019년 유통 트렌드는
# 17 :  연초 공공분양 봇물…시세보다 낮아 관심 폭발
# 18 :  국민은행 19년 만에 총파업 돌입...3월 말까지 추가 파업 예고
# 19 :  [CES 2019] LG전자, 세계 최초로 화면 돌돌 마는 롤러블 올레드 TV 공개
# 20 :  [CES 2019] 비어만 현대차 사장 “고성능 수소차, 현대차 아니면 누가 하나”
# 21 :  D램 침체에 직격탄, 삼성전자 반도체서 영업익 5조원 증발
# 22 :  빅딜로 새해 연 박정호 사장...SK브로드밴드·유료방송 M&A 어떻게 풀까
# 23 :  年 78만원에 강제 가계부 작성 논란…강남구 절반은 불응
# 24 :  [르포] 국민銀, 총파업에 영업점 곳곳 사과문…혼란은 없어
# 25 :  국민은행 노조 "협상 결렬"…19년 만에 총파업 현실화
# 26 :  11월 경상흑자 50.6억달러…반도체 둔화에 수출 '경고등'
# 27 :  "바이오 큰 장 열렸다"...JP모건 콘퍼런스 개막
# 28 :  [인터뷰] 정신아 카카오벤처스 대표 “꼰대 안 되는 게 목표죠”
# 29 :  농협 하나로 '갑질'...200일 지난 생선 반품, 허위 매출, 고위직 낙하산
# 30 :  최저임금 ‘16.4% 인상 쇼크’ 재연 없앤다
# 30 건  완료========================================================
# 현재까지 총 240 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 09일의 뉴스 수집 중 ===================================
# 1 :  정치영화 만들더니...CJ, 영화시장 3위 '추락'
# 2 :  금융위기급 고용참사…민간 일자리 날린 ‘일자리 정부’
# 3 :  주택시장 찬바람에 이사·인테리어 산업은 '보릿고개'
# 4 :  100만원 아동용 롱패딩 품절…고가 아동용품 시장 호황
# 5 :  작년 취업자 증가 10만명 밑돌아…9년만에 최저(종합)
# 6 :  [CES 2019] 현대차, 홀로그램 AR 내비게이션 탑재한 G80 세계 최초 공개
# 7 :  상어가 효자네…빌보드 32위 소식에 삼성출판사 상한가
# 8 :  어느 쪽이 중국기술일까… 미국이 하면 중국도 한다
# 9 :  [CES 2019] 화웨이 '노치'없는 풀스크린·홀스크린 스마트폰 선보여
# 10 :  '집 사느라'…작년 3분기 가계 부채 대비 자산 비율 75개월來 최저
# 11 :  작년 취업자 증가 9년만에 최저…홍남기 “세부적으론 고용 개선”
# 12 :  불황에도 잘나가는 패션 브랜드...Z세대 공략 통했다
# 13 :  [CES 2019] 현대차, 걸어다니는 車 ‘엘리베이트’ 콘셉트카 공개
# 14 :  [CES 2019] TV시장 8K 대격돌...구글·아마존 AI 장착은 기본, 애플도 빗장 풀어
# 15 :  급등한 공시가격 불만 달래기… 기초연금 탈락 피해 줄인다
# 16 :  한진중공업 수비크조선소 미지급대금 700억원…협력업체 피해 우려
# 17 :  [CES 2019] 삼성, 하만 디지털 콕핏 공개…"1호 고객은 중국차 업체"
# 18 :  [단독] 돼지 수천마리 몰래 판 사조동아원, 美 카길에 패소
# 19 :  [2019 신차]⑦ BMW 7세대 3시리즈, 역동적 디자인과 효율성으로 무장
# 20 :  [단독] 한수원, 기술현안관리단 신설 "정비기간 줄여 원전가동률 높인다"
# 21 :  반려견도 좋지만… 노후엔 돼지 몰고 가세요
# 22 :  세금·물량·대출…"주택시장 가를 3대 변수"
# 23 :  홍남기 부총리 "올해 공공기관 2만3000명 이상 채용"
# 24 :  '모난' 강남 아파트, 추락 땐 '억소리'
# 25 :  바이오시밀러 족쇄 풀린 셀트리온…국내·외 특허 문제 해소
# 26 :  신동주, 출소한 신동빈에 화해 편지...롯데 "진정성 없다"
# 27 :  작년 취업자 증가 10만명 밑돌아… 9년만에 최저치(1보)
# 28 :  구직자 늘어나는 미국, 182만명 '그냥 쉬는' 한국
# 29 :  부사장 車가 상무 車보다 꼭 커야하나요?
# 30 :  부산 센텀시티∙마린시티 잇는 새 주거복합단지 부산 오션시티 푸르지오
# 30 건  완료========================================================
# 현재까지 총 270 건의 기사를 수집 완료 했습니다
#
#
#
#
# 2019년 01월 10일의 뉴스 수집 중 ===================================
# 1 :  "10년된 치킨집 무조건 문닫아라" bhc·BBQ 일방적 계약해지 '갑질'
