# %%
# 연습문제 9-3: 쿠팡 분야별 베스트 상품 크롤러

#Step 1. 필요한 모듈과 라이브러리를 로딩합니다.

from bs4 import BeautifulSoup
from selenium import webdriver

import time
import sys
import re
import math
import numpy 
import pandas as pd   
import xlwt 
import random
import os

import urllib.request
import urllib

#Step 2. 사용자에게 검색어 키워드를 입력 받습니다.

print("=" *80)
print("연습문제 9-3. 쿠팡 사이트의 Best Seller 상품 정보 추출하기 ")
print("=" *80)

query_txt='쿠팡'
query_url='https://www.coupang.com/'

sec = input('''
1.패션의류/잡화-남성  2.패션의류/잡화-여성  3.뷰티              4.출산/유아동
5.식품                6.주방용품            7.생활용품          8.홈인테리어
9.가전/디지털         10.스포츠/레저        11.자동차용품       12.도서/음반/DVD
13.완구/취미          14.문구/오피스        15.반려동물용품     16.헬스/건강식품
    

1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: ''')

cnt = int(input('2.크롤링 할 건수는 몇건입니까?(최대 60건): '))

f_dir = input("3.파일을 저장할 폴더명만 쓰세요(예:c:\\temp\\):")
print("\n")

if sec == '1' :
      sec_name='패션의류_잡화-남성'
elif sec =='2' :
      sec_name='패션의류_잡화-여성'
elif sec =='3' :
      sec_name='뷰티'
elif sec =='4' :
      sec_name='출산_유아동'
elif sec =='5' :
      sec_name='식품'
elif sec =='6' :
      sec_name='주방용품'
elif sec =='7' :
      sec_name='생활용품'
elif sec =='8' :
      sec_name='홈인테리어'
elif sec =='9' :
      sec_name='가전_디지털'
elif sec =='10' :
      sec_name='스포츠_레저'
elif sec =='11' :
      sec_name='자동차용품'
elif sec =='12' :
      sec_name='도서_음반_DVD'
elif sec =='13' :
      sec_name='완구_취미'
elif sec =='14' :
      sec_name='문구_오피스'
elif sec =='15' :
      sec_name='반려동물용품'
elif sec =='16' :
      sec_name='헬스_건강식품'

                   
if cnt > 30 :
      print("    요청 건수가 많아서 시간이 제법 소요되오니 잠시만 기다려 주세요~~")
else :
      print("    요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요~~")
      
# 저장될 파일위치와 이름을 지정합니다
now = time.localtime()
s = '%04d-%02d-%02d-%02d-%02d-%02d' % (now.tm_year, now.tm_mon, now.tm_mday, now.tm_hour, now.tm_min, now.tm_sec)

os.makedirs(f_dir+s+'-'+query_txt+'-'+sec_name)
os.chdir(f_dir+s+'-'+query_txt+'-'+sec_name)

ff_dir=f_dir+s+'-'+query_txt+'-'+sec_name
ff_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.txt'
fc_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.csv'
fx_name=f_dir+s+'-'+query_txt+'-'+sec_name+'\\'+s+'-'+query_txt+'-'+sec_name+'.xls'

s_time = time.time( )


#Step 3. 크롬 드라이버를 사용해서 웹 브라우저를 실행합니다.
path = "c:/spiderware_0.1/engine_238/engine.exe"
driver = webdriver.Chrome(path)
    
driver.get(query_url)
time.sleep(5)


# 분야별 더보기 버튼을 눌러 페이지를 엽니다
driver.find_element_by_xpath("""//*[@id="header"]/div""").click( )

if sec == '1' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click( )
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[3]/a""").click()
elif sec == '2' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/a""").click( )
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[1]/div/div/ul/li[2]/a""").click()
elif sec == '3' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[2]/a""").click( )
elif sec == '4' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[3]/a""").click( )
elif sec == '5' : 
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[4]/a""").click( )
elif sec == '6' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[5]/a""").click( )
elif sec == '7' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[6]/a""").click( )
elif sec == '8' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[7]/a""").click( )
elif sec == '9' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[8]/a""").click( )
elif sec == '10' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[9]/a""").click( )
elif sec == '11' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[10]/a""").click( )
elif sec == '12' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[11]/a""").click( )
elif sec == '13' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[12]/a""").click( )
elif sec == '14' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[13]/a""").click( )
elif sec == '15' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[14]/a""").click( )
elif sec == '16' :
      driver.find_element_by_xpath("""//*[@id="gnbAnalytics"]/ul[1]/li[15]/a""").click( )

#Step 5. 화면을 스크롤해서 아래로 이동합니다

def scroll_down(driver):
      driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
      time.sleep(1)
scroll_down(driver)

ranking2=[]
title2=[]
o_price2=[]
p_price2=[]
discount2 = []

score2=[]
sat_count2=[]


#Step 6. 내용을 수집합니다
print("\n")
print("===== 곧 수집된 결과를 출력합니다 ^^ ===== ")
print("\n")

time.sleep(2)

html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
        
count = 0

#이미지 추출하기
img_src2=[]   # 이미지 URL 저장변수
file_no = 0

item_result = soup.find('ul','baby-product-list')
item_result2 = item_result.find_all('li')

# 내용 추출하기

img_dir = ff_dir+"\\images"
os.makedirs(img_dir)
os.chdir(img_dir)


for li in item_result2:

            count += 1
            
            if count > cnt :
                break
            
            try :
              photo = li.find('dt','image').find('img')['src']
            except AttributeError :
              continue
            file_no += 1
            full_photo = 'https:' + photo
            urllib.request.urlretrieve(full_photo,str(file_no)+'.jpg')
            time.sleep(0.5)

            if cnt < file_no :
              break

            
            f = open(ff_name, 'a',encoding='UTF-8')
            f.write("-----------------------------------------------------"+"\n")

            print("-" *70)
            
            
            ranking = count
            print("1.판매순위:",ranking)
            f.write('1.판매순위:'+ str(ranking) + "\n")
             
            try :
               t = li.find('div',class_='name').get_text().replace("\n","")
            except AttributeError :
               title = ''
               print(title.replace("\n",""))
               f.write('2.제품소개:'+ title + "\n")
            else :
               title = t.replace("\n","").strip()
               print("2.제품소개:", title.replace("\n","").strip())                  
               f.write('2.제품소개:'+ title + "\n")
            
            try :
               o_price = li.find('del','base-price').get_text().replace("\n","")
            except AttributeError :
               o_price = '0'
               print("3.원래가격:",o_price.replace("\n",""))
            else :
               print("3.원래가격:",o_price.replace("\n",""))
               f.write('3.원래가격:'+ o_price + "\n")

            try :
               p_price = li.find('strong','price-value').get_text().replace("\n","")
            except AttributeError :
               p_price = '0'
               print("4.판매가격:", p_price.replace("\n",""))
            else :
               print("4.판매가격:", p_price.replace("\n",""))
               f.write('4.판매가격:'+ p_price + "\n")

            try :
               discount = li.find('span','discount-percentage').get_text().replace("\n","")
            except AttributeError :
               discount = 0
               print("5:할인률", discount)
            else :
               print("5:할인률", discount)
               f.write('5.할인율:'+ discount + "\n")
     
             
            try :
                sat_count = li.find('span','rating-total-count').get_text().replace("(","").replace(")","")
            except (IndexError,AttributeError) :
                sat_count='0'
                print('6.상품평 수: ',sat_count)
                f.write('6.상품평 수:'+ sat_count + "\n")
            else :
                print('6.상품평 수:',sat_count)
                f.write('6.상품평 수:'+ sat_count + "\n")


            try :
               score= li.find('em','rating').get_text()
            except AttributeError :
               score='0'
               print('7.평점: 5 /',score)
            else :     
               print('7.평점: 5 /',score)
               f.write('7.평점: 5 /'+ score + "\n")

                                    
            print("-" *70)
             
             
            f.close( )
              
            time.sleep(0.5)

             
             
            ranking2.append(ranking)
            title2.append(title.replace("\n",""))
            o_price2.append(o_price.replace("\n",""))
            p_price2.append(p_price.replace("\n",""))
            discount2.append(discount)
            score2.append(score)

            try :   
              sat_count2.append(sat_count)
            except IndexError :
               sat_count2.append(0)

          
#step 9. 엑셀 형태로 저장하기
              
co_best_seller = pd.DataFrame()
co_best_seller['판매순위']=ranking2
co_best_seller['제품소개']=pd.Series(title2)
co_best_seller['제품정가']=pd.Series(o_price2)
co_best_seller['제품판매가']=pd.Series(p_price2)
co_best_seller['할인율']=pd.Series(discount2)
co_best_seller['상품평수']=pd.Series(sat_count2)
co_best_seller['상품평점']=pd.Series(score2)


# csv 형태로 저장하기
co_best_seller.to_csv(fc_name,encoding="utf-8-sig",index=True)

# 엑셀 형태로 저장하기
co_best_seller.to_excel(fx_name ,index=True)

e_time = time.time( )
t_time = e_time - s_time


count -= 1
print("\n")
print("=" *80)
print("1.요청된 총 %s 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 %s 건입니다" %(cnt,count))
print("2.총 소요시간은 %s 초 입니다 " %round(t_time,1))
print("3.파일 저장 완료: txt 파일명 : %s " %ff_name)
print("4.파일 저장 완료: csv 파일명 : %s " %fc_name)
print("5.파일 저장 완료: xls 파일명 : %s " %fx_name)
print("=" *80)

#이미지 삽입하기

import win32com.client as win32   
import win32api  
                

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Open(fx_name)
sheet = wb.ActiveSheet
sheet.Columns(3).ColumnWidth = 30   
row_cnt = cnt+1
sheet.Rows("2:%s" %row_cnt).RowHeight = 120   

ws = wb.Sheets("Sheet1")
col_name2=[]
file_name2=[]

for a in range(2,cnt+2) :
      col_name='C'+str(a)
      col_name2.append(col_name)

for b in range(1,cnt+1) :
      file_name=img_dir+'\\'+str(b)+'.jpg'
      file_name2.append(file_name)
      
for i in range(0,cnt) :
      rng = ws.Range(col_name2[i])
      image = ws.Shapes.AddPicture(file_name2[i], False, True, rng.Left, rng.Top, 130, 100)
      excel.Visible=True
      excel.ActiveWorkbook.Save()


driver.close( )
# Out:
# ================================================================================
# 연습문제 9-3. 쿠팡 사이트의 Best Seller 상품 정보 추출하기
# ================================================================================
#
# 1.패션의류/잡화-남성  2.패션의류/잡화-여성  3.뷰티              4.출산/유아동
# 5.식품                6.주방용품            7.생활용품          8.홈인테리어
# 9.가전/디지털         10.스포츠/레저        11.자동차용품       12.도서/음반/DVD
# 13.완구/취미          14.문구/오피스        15.반려동물용품     16.헬스/건강식품
#
#
# 1.위 분야 중에서 자료를 수집할 분야의 번호를  선택하세요: 3
#     2.크롤링 할 건수는 몇건입니까?(최대 60건): 10
#     3.파일을 저장할 폴더명만 쓰세요(예:c:\temp\):c:\data\
#
#
#     요청하신 데이터를 수집하고 있으니 잠시만 기다려 주세요~~
#
#
# ===== 곧 수집된 결과를 출력합니다 ^^ =====
#
#
# ----------------------------------------------------------------------
# 1.판매순위: 1
# 2.제품소개: 삐아 라스트 벨벳 립 틴트4 5g, 17 꽃보다 살랑, 1개
# 3.원래가격: 12,000
# 4.판매가격: 5,700
# 5:할인률 52%
# 6.상품평 수: 5926
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 2
# 2.제품소개: 페리페라 잉크 더 에어리 벨벳 립스틱 3.6g, 05사복여신, 1개
# 3.원래가격: 11,000
# 4.판매가격: 7,540
# 5:할인률 31%
# 6.상품평 수: 485
# 7.평점: 5 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 3
# 2.제품소개: 페리페라 잉크 더 에어리 벨벳 틴트 4g, 레드맛집, 1개
# 3.원래가격: 9,000
# 4.판매가격: 6,220
# 5:할인률 30%
# 6.상품평 수: 496
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 4
# 2.제품소개: 맥퀸뉴욕 페이크업 3색 쉐딩 9g + 쉐딩브러쉬, 2종, 1세트
# 3.원래가격: 0
# 4.판매가격: 7,900
# 5:할인률 0
# 6.상품평 수: 1701
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 5
# 2.제품소개: 삐아 라스트 벨벳 립 틴트6 5g, 28 핑크스릴러, 1개
# 3.원래가격: 0
# 4.판매가격: 5,700
# 5:할인률 0
# 6.상품평 수: 90
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 6
# 2.제품소개: 부케가르니 히말라야 허브 나드 샴푸, 1L, 1개
# 3.원래가격: 22,000
# 4.판매가격: 10,900
# 5:할인률 50%
# 6.상품평 수: 9963
# 7.평점: 5 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 7
# 2.제품소개: 맥퀸뉴욕 쥬얼포텐 아이글리터, 1키튼 다이아, 1개
# 3.원래가격: 4,550
# 4.판매가격: 4,380
# 5:할인률 3%
# 6.상품평 수: 1288
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 8
# 2.제품소개: 부케가르니 바디워시 플로럴 머스크, 520ml, 1개
# 3.원래가격: 13,000
# 4.판매가격: 7,510
# 5:할인률 42%
# 6.상품평 수: 630
# 7.평점: 5 / 4.0
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 9
# 2.제품소개: 일리윤 세라마이드 아토 수딩 젤, 150ml, 2개입
# 3.원래가격: 35,800
# 4.판매가격: 17,900
# 5:할인률 50%
# 6.상품평 수: 68
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
# ----------------------------------------------------------------------
# 1.판매순위: 10
# 2.제품소개: 클리오 킬 커버 파운웨어 쿠션 XP 본품 + 리필 세트, 03 린넨, 1세트
# 3.원래가격: 32,000
# 4.판매가격: 18,170
# 5:할인률 43%
# 6.상품평 수: 5973
# 7.평점: 5 / 4.5
# ----------------------------------------------------------------------
#
#
# ================================================================================
# 1.요청된 총 10 건의 리뷰 중에서 실제 크롤링 된 리뷰수는 10 건입니다
# 2.총 소요시간은 29.3 초 입니다
# 3.파일 저장 완료: txt 파일명 : c:\data\2019-05-22-10-31-26-쿠팡-뷰티\2019-05-22-10-31-26-쿠팡-뷰티.txt
# 4.파일 저장 완료: csv 파일명 : c:\data\2019-05-22-10-31-26-쿠팡-뷰티\2019-05-22-10-31-26-쿠팡-뷰티.csv
# 5.파일 저장 완료: xls 파일명 : c:\data\2019-05-22-10-31-26-쿠팡-뷰티\2019-05-22-10-31-26-쿠팡-뷰티.xls
# ================================================================================
